# %% [markdown]
# ## Testing 5s runs vs morotti supplement

# %% [markdown]
# Mouse
# <code>
# python runShannonTest.py -dt 0.1 -stim 999 -jit -T 5000 -odeName shannon_2004_mouse.ode -name mouse_5.pickle
# </code>
#
# Rabbit
# <code>
# python runShannonTest.py -dt 0.1 -stim 999 -jit -T 5000 -odeName shannon_2004.ode -name rabbit_5.pickle
# </code>

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gotranJIT
from gotran.model.loadmodel import load_ode

# %%
import analyzeODE as ao
import numpy as np
# Out:
# WARNING: ode idx is hardcoded

# %% [markdown]
# <font color=red>I believe i have tools for this already</font>

# %%
cases = dict()

class empty:pass

case = empty()
case.caseName = "mouse_5"
case.fileName = case.caseName+".pickle"
case.data = ao.readPickle(case.fileName) 
cases[case.caseName] = case


case = empty()
case.caseName = "rabbit_5"
case.fileName = case.caseName+".pickle"
case.data = ao.readPickle(case.fileName) 
cases[case.caseName] = case
# Out:
# Reading mouse_5.pickle
# Reading rabbit_5.pickle

# %% [markdown]
# Print currents

# %%
case = cases['mouse_5']
j_idx = case.data['j_idx']
for i, stringer in enumerate(j_idx):
    if "i_" in stringer:
        1
        #print stringer

# %% [markdown]
# ### Currents

# %%
from analyzeODE import PlotMorotti

# %% [markdown]
# <code>
# montage *g -tile 3x -geometry '+2+2+2+2>' /net/share/shared/papers/despa/current_compare.png
# </code>

# %%
PlotMorotti(cases,trange=[4e3,4.2e3])
# Out:
# i_kur  not found
# i_ss
#   not found

# %% [markdown]
# ### I_to

# %%
fluxes = ["i_tof", "i_tos"]  # add the rest of the contributors here 
case = cases['mouse_5']
t = case.data['t']
ito = np.zeros(np.shape(t)[0])

j = case.data['j']
j_idx = case.data['j_idx']
for i,flux in enumerate(fluxes):
    idx1 = j_idx.index(flux)
    ito+=j[:,idx1]
    
plt.plot(t,ito,label="I_to [A/F]")
plt.xlim(trange)
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-d6906ac4298a> in <module>()
#      11
#      12 plt.plot(t,ito,label="I_to [A/F]")
# ---> 13 plt.xlim(trange)
#      14 plt.legend()
#
# NameError: name 'trange' is not defined

# %% [markdown]
# ### Extended mouse case
#
# <font color="red">60 s seems too long for stable solutions </font>

# %%
caseExtended = empty()
caseExtended.caseName = "mouse_60" 
caseExtended.fileName = caseExtended.caseName+".pickle"
caseExtended.data = ao.readPickle(caseExtended.fileName) 
#cases[case.caseName] = case
# Out:
# Reading mouse_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["V", "Cai", "Ca_SR","Nai"]
for i,state in enumerate(states):
  ao.PlotPickleData(caseExtended.data,idxName=state, 
                          ylabel=state)#,trange=[50e3,50.3e3])
  plt.gcf().savefig(root+caseExtended.caseName+"_%s"%state+".png")
# Out:
# /usr/lib/python2.7/dist-packages/matplotlib/axes/_axes.py:476: UserWarning: No labelled objects found. Use label='...' kwarg on individual plots.
#   warnings.warn("No labelled objects found. "

# %% [markdown]
# <code>
# python runShannonTest.py -dt 0.1 -stim 999 -var PCa 0.0011583  -jit -T 60000 -odeName shannon_2004_mouse.ode -name mouse_PCa_60.pickle
# </code>

# %%
caseExtendedIncr = empty()
caseExtendedIncr.caseName = "mouse_PCa_60" 
caseExtendedIncr.fileName = caseExtendedIncr.caseName+".pickle"
caseExtendedIncr.data = ao.readPickle(caseExtendedIncr.fileName) 
#cases[case.caseName] = case
# Out:
# Reading mouse_PCa_60.pickle

# %% [markdown]
# <code>
# montage baseline*g -tile 2x -geometry '+2+2+2+2>' /net/share/shared/papers/despa/baseline_incrPCa_comp.png
# </code>

# %%
root="/net/share/shared/papers/despa/"
states = ["V", "Cai", "Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended.data,data2=caseExtendedIncr.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.3e3],
                          case1legend=caseExtended.caseName,
                          case2legend=caseExtendedIncr.caseName)
        plt.tight_layout()
        plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %% [markdown]
# ### Paper Figures

# %% [markdown]
# Figure 1

# %% [markdown]
# ## Baseline

# %%
caseExtended1Hz = empty()
caseExtended1Hz.caseName = "mouse_freq1p0_60" 
caseExtended1Hz.fileName = caseExtended1Hz.caseName+".pickle"
caseExtended1Hz.data = ao.readPickle(caseExtended1Hz.fileName)
# Out:
# Reading mouse_freq1p0_60.pickle

# %%
s = caseExtended1Hz.data['s']
s_idx = caseExtended1Hz.data['s_idx']
idx = s_idx.index("Cai")

maxBaseline_Cai = np.amax(s[200e3:205e3,idx])
print maxBaseline_Cai
minBaseline_Cai = np.amin(s[200e3:205e3,idx])
print minBaseline_Cai
diffBaseline_Cai = maxBaseline_Cai - minBaseline_Cai
print diffBaseline_Cai
# Out:
# 0.000569281273533
# 0.00010165257428
# 0.000467628699253

# %%
s = caseExtended1Hz.data['s']
s_idx = caseExtended1Hz.data['s_idx']
idx = s_idx.index("Ca_SR")

maxBaseline_CaSR = np.amax(s[200e3:205e3,idx])
print maxBaseline_CaSR
minBaseline_CaSR = np.amin(s[200e3:205e3,idx])
print minBaseline_CaSR
diffBaseline_CaSR=maxBaseline_CaSR-minBaseline_CaSR
print diffBaseline_CaSR
# Out:
# 0.593064263418
# 0.303185301413
# 0.289878962005

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend='Baseline')
        plt.tight_layout()
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/Baseline_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
p_idx = caseExtended1Hz.data['p_idx']
p = caseExtended1Hz.data['p']
print p[p_idx.index('G_CaBk')]
print p[p_idx.index('G_CaBk')]*1.075
# Out:
# 0.0007539
# 0.0008104425

# %%
p_idx = caseExtended1Hz.data['p_idx']
p = caseExtended1Hz.data['p']
print p[p_idx.index('G_NaBk')]
print p[p_idx.index('G_NaBk')]*1.075
# Out:
# 0.001337
# 0.001437275

# %%
p_idx = caseExtended1Hz.data['p_idx']
p = caseExtended1Hz.data['p']
print p[p_idx.index('V_max_Jpump')]
print p[p_idx.index('V_max_Jpump')]*2
# Out:
# 0.00702
# 0.01404

# %%
p_idx = caseExtended1Hz.data['p_idx']
p = caseExtended1Hz.data['p']
print p[p_idx.index('PCa')]
print p[p_idx.index('PCa')]*1.25
# Out:
# 0.000891
# 0.00111375

# %%
1.875+0.125
# Out:
# 2.0

# %%
p_idx = caseExtended1Hz.data['p_idx']
p = caseExtended1Hz.data['p']
print p[p_idx.index('V_max_INaCa')]
print p[p_idx.index('V_max_INaCa')]*1.25
# Out:
# 1.0
# 1.25

# %% [markdown]
# ## Increase Leak

# %%
caseAmylin1p05 = empty()
caseAmylin1p05.caseName = "mouse_leak1p05x_freq1p0_60" 
caseAmylin1p05.fileName = caseAmylin1p05.caseName+".pickle"
caseAmylin1p05.data = ao.readPickle(caseAmylin1p05.fileName)
# Out:
# Reading mouse_leak1p05x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p05.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline",
                          case2legend="Amylin Incubation")
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p10 = empty()
caseAmylin1p10.caseName = "mouse_leak1p10x_freq1p0_60" 
caseAmylin1p10.fileName = caseAmylin1p10.caseName+".pickle"
caseAmylin1p10.data = ao.readPickle(caseAmylin1p10.fileName)
# Out:
# Reading mouse_leak1p10x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p10.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p10.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p125 = empty()
caseAmylin1p125.caseName = "mouse_leak1p125x_freq1p0_60" 
caseAmylin1p125.fileName = caseAmylin1p125.caseName+".pickle"
caseAmylin1p125.data = ao.readPickle(caseAmylin1p125.fileName)
# Out:
# Reading mouse_leak1p125x_freq1p0_60.pickle

# %%
s = caseAmylin1p125.data['s']
s_idx = caseAmylin1p125.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p125_CaSR = np.amax(s[200e3:205e3,idx])
print max1p125_CaSR
min1p125_CaSR = np.amin(s[200e3:205e3,idx])
print min1p125_CaSR
diff1p125_CaSR=max1p125_CaSR-min1p125_CaSR
print diff1p125_CaSR
# Out:
# 0.610546668458
# 0.296342779949
# 0.314203888509

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p125.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p125.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p25 = empty()
caseAmylin1p25.caseName = "mouse_leak1p25x_freq1p0_60" 
caseAmylin1p25.fileName = caseAmylin1p25.caseName+".pickle"
caseAmylin1p25.data = ao.readPickle(caseAmylin1p25.fileName)
# Out:
# Reading mouse_leak1p25x_freq1p0_60.pickle

# %%
s = caseAmylin1p25.data['s']
s_idx = caseAmylin1p25.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p25_CaSR = np.amax(s[200e3:205e3,idx])
print max1p25_CaSR
min1p25_CaSR = np.amin(s[200e3:205e3,idx])
print min1p25_CaSR
diff1p25_CaSR=max1p25_CaSR-min1p25_CaSR
print diff1p25_CaSR
# Out:
# 0.628225629516
# 0.289236417419
# 0.338989212096

# %%
s = caseAmylin1p25.data['s']
s_idx = caseAmylin1p25.data['s_idx']
idx = s_idx.index("Ca_SR")

maxAmylin_CaSR = np.amax(s[200e3:205e3,idx])
print maxAmylin_CaSR
minAmylin_CaSR = np.amin(s[200e3:205e3,idx])
print minAmylin_CaSR
diffAmylin_CaSR=maxAmylin_CaSR-minAmylin_CaSR
print diffAmylin_CaSR
# Out:
# 0.628225629516
# 0.289236417419
# 0.338989212096

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p25.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p25.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
#newCases = {'baseline',caseExtended1Hz,'nothappy',caseAmylin1p25}
newCases = dict()
newCases['baseline']=caseExtended1Hz
newCases['nothappy']=caseAmylin1p25
PlotMorotti(newCases,'baseline','nothappy',trange=[28e3,28.3e3])

# %%
caseAmylin1p375 = empty()
caseAmylin1p375.caseName = "mouse_leak1p375x_freq1p0_60" 
caseAmylin1p375.fileName = caseAmylin1p375.caseName+".pickle"
caseAmylin1p375.data = ao.readPickle(caseAmylin1p375.fileName)
# Out:
# Reading mouse_leak1p375x_freq1p0_60.pickle

# %%
s = caseAmylin1p375.data['s']
s_idx = caseAmylin1p375.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p375_CaSR = np.amax(s[200e3:205e3,idx])
print max1p375_CaSR
min1p375_CaSR = np.amin(s[200e3:205e3,idx])
print min1p375_CaSR
diff1p375_CaSR=max1p375_CaSR-min1p375_CaSR
print diff1p375_CaSR
# Out:
# 0.645961073268
# 0.282146449914
# 0.363814623353

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p375.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p375.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p5 = empty()
caseAmylin1p5.caseName = "mouse_leak1p5x_freq1p0_60" 
caseAmylin1p5.fileName = caseAmylin1p5.caseName+".pickle"
caseAmylin1p5.data = ao.readPickle(caseAmylin1p5.fileName)
# Out:
# Reading mouse_leak1p5x_freq1p0_60.pickle

# %%
s = caseAmylin1p5.data['s']
s_idx = caseAmylin1p5.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p5_CaSR = np.amax(s[200e3:205e3,idx])
print max1p5_CaSR
min1p5_CaSR = np.amin(s[200e3:205e3,idx])
print min1p5_CaSR
diff1p5_CaSR=max1p5_CaSR-min1p5_CaSR
print diff1p5_CaSR
# Out:
# 0.663503202957
# 0.275379219075
# 0.388123983882

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p5.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p5.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")
# Out:
# The history saving thread hit an unexpected error (OperationalError('database is locked',)).History will not be written to the database.

# %%
caseAmylin1p625 = empty()
caseAmylin1p625.caseName = "mouse_leak1p625x_freq1p0_60" 
caseAmylin1p625.fileName = caseAmylin1p625.caseName+".pickle"
caseAmylin1p625.data = ao.readPickle(caseAmylin1p625.fileName)
# Out:
# Reading mouse_leak1p625x_freq1p0_60.pickle

# %%
s = caseAmylin1p625.data['s']
s_idx = caseAmylin1p625.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p625_CaSR = np.amax(s[200e3:205e3,idx])
print max1p625_CaSR
min1p625_CaSR = np.amin(s[200e3:205e3,idx])
print min1p625_CaSR
diff1p625_CaSR=max1p625_CaSR-min1p625_CaSR
print diff1p625_CaSR
# Out:
# 0.680457207512
# 0.269270294847
# 0.411186912664

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p625.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p625.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p75 = empty()
caseAmylin1p75.caseName = "mouse_leak1p75x_freq1p0_60" 
caseAmylin1p75.fileName = caseAmylin1p75.caseName+".pickle"
caseAmylin1p75.data = ao.readPickle(caseAmylin1p75.fileName)
# Out:
# Reading mouse_leak1p75x_freq1p0_60.pickle

# %%
s = caseAmylin1p75.data['s']
s_idx = caseAmylin1p75.data['s_idx']
idx = s_idx.index("Ca_SR")

max1p75_CaSR = np.amax(s[200e3:205e3,idx])
print max1p75_CaSR
min1p75_CaSR = np.amin(s[200e3:205e3,idx])
print min1p75_CaSR
diff1p75_CaSR=max1p75_CaSR-min1p75_CaSR
print diff1p75_CaSR
# Out:
# 0.696213380082
# 0.264221737365
# 0.431991642716

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p75.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p75.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin1p875 = empty()
caseAmylin1p875.caseName = "mouse_leak1p875x_freq1p0_60" 
caseAmylin1p875.fileName = caseAmylin1p875.caseName+".pickle"
caseAmylin1p875.data = ao.readPickle(caseAmylin1p875.fileName)
# Out:
# Reading mouse_leak1p875x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin1p875.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin1p875.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin2 = empty()
caseAmylin2.caseName = "mouse_leak2x_freq1p0_60" 
caseAmylin2.fileName = caseAmylin2.caseName+".pickle"
caseAmylin2.data = ao.readPickle(caseAmylin2.fileName)
# Out:
# Reading mouse_leak2x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin2.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin2.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin3 = empty()
caseAmylin3.caseName = "mouse_leak3x_freq1p0_60" 
caseAmylin3.fileName = caseAmylin3.caseName+".pickle"
caseAmylin3.data = ao.readPickle(caseAmylin3.fileName)
# Out:
# Reading mouse_leak3x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin3.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin3.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseAmylin4 = empty()
caseAmylin4.caseName = "mouse_leak4x_freq1p0_60" 
caseAmylin4.fileName = caseAmylin4.caseName+".pickle"
caseAmylin4.data = ao.readPickle(caseAmylin4.fileName)
# Out:
# Reading mouse_leak4x_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin4.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseAmylin4.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-adf555702186> in <module>()
#       2 states = ["Cai","V"]
#       3 for i,state in enumerate(states):
# ----> 4         ao.PlotPickleData(caseExtended1Hz.data,data2=caseAmylin4.data,idxName=state,
#       5                           ylabel=state,trange=[50e3,50.5e3],
#       6                           case1legend=caseExtended1Hz.caseName,
#
# NameError: name 'ao' is not defined

# %% [markdown]
# ## Decrease SERCA uptake

# %%
caseSERCA0p5 = empty()
caseSERCA0p5.caseName = "mouse_decrSERCAuptake0p50_freq1p0_60" 
caseSERCA0p5.fileName = caseSERCA0p5.caseName+".pickle"
caseSERCA0p5.data = ao.readPickle(caseSERCA0p5.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseSERCA0p5.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseSERCA0p5.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseSERCA0p625 = empty()
caseSERCA0p625.caseName = "mouse_decrSERCAuptake0p625_freq1p0_60" 
caseSERCA0p625.fileName = caseSERCA0p625.caseName+".pickle"
caseSERCA0p625.data = ao.readPickle(caseSERCA0p625.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p625_freq1p0_60.pickle

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseSERCA0p625.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseSERCA0p625.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseSERCA0p75 = empty()
caseSERCA0p75.caseName = "mouse_decrSERCAuptake0p75_freq1p0_60" 
caseSERCA0p75.fileName = caseSERCA0p75.caseName+".pickle"
caseSERCA0p75.data = ao.readPickle(caseSERCA0p75.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseSERCA0p75.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseSERCA0p75.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %%
caseSERCA0p875 = empty()
caseSERCA0p875.caseName = "mouse_decrSERCAuptake0p875_freq1p0_60" 
caseSERCA0p875.fileName = caseSERCA0p875.caseName+".pickle"
caseSERCA0p875.data = ao.readPickle(caseSERCA0p875.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseSERCA0p875.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseSERCA0p875.caseName)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")

# %% [markdown]
# ## HIP case

# %%
caseHIP = empty()
caseHIP.caseName = "mouse_decrSERCAuptake0p50_leak1p25x_freq1p0_60" 
caseHIP.fileName = caseHIP.caseName+".pickle"
caseHIP.data = ao.readPickle(caseHIP.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_leak1p25x_freq1p0_60.pickle

# %%
s = caseHIP.data['s']
s_idx = caseHIP.data['s_idx']
idx = s_idx.index("Ca_SR")

maxHIP_CaSR = np.amax(s[200e3:205e3,idx])
print maxHIP_CaSR
minHIP_CaSR = np.amin(s[200e3:205e3,idx])
print minHIP_CaSR
diffHIP_CaSR=maxHIP_CaSR-minHIP_CaSR
print diffHIP_CaSR
# Out:
# 0.582590846849
# 0.281859717331
# 0.300731129518

# %%
s = caseHIP.data['s']
s_idx = caseHIP.data['s_idx']
idx = s_idx.index("Cai")

maxHIP_Cai = np.amax(s[200e3:205e3,idx])
print maxHIP_Cai
minHIP_Cai = np.amin(s[200e3:205e3,idx])
print minHIP_Cai
diffHIP_Cai = maxHIP_Cai -minHIP_Cai
print diffHIP_Cai
# Out:
# 0.000689803875062
# 0.000127753374135
# 0.000562050500927

# %%
root="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseHIP.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],ylim=(0.25,0.65),
                          case1legend="Baseline",
                          case2legend="+HIP")
        plt.legend(bbox_to_anchor=(3.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()
        outFile=root+"Baseline_vs_HIP_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)        
        
     #   print caseExtended1Hz.data

# %% [markdown]
# ## Increase LCC

# %%
caseLCC = empty()
caseLCC.caseName = "mouse_lcc1p25x_freq1p0_60" 
caseLCC.fileName = caseLCC.caseName+".pickle"
caseLCC.data = ao.readPickle(caseLCC.fileName)

# %%
s = caseLCC.data['s']
s_idx = caseLCC.data['s_idx']
idx = s_idx.index("Ca_SR")

maxLCC_CaSR = np.amax(s[200e3:205e3,idx])
print maxLCC_CaSR
minLCC_CaSR = np.amin(s[200e3:205e3,idx])
print minLCC_CaSR
diffLCC_CaSR=maxLCC_CaSR-minLCC_CaSR
print diffLCC_CaSR

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseLCC.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.9e3],
                          case1legend="Baseline",
                          case2legend="+LCC")
        plt.legend(bbox_to_anchor=(3.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()
        #plt.gcf().savefig(root+"baseline_vs_IncrPCa_"+"_%s"%state+".png")
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/LCC_%s.png"%i
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)        
     #   print caseExtended1Hz.data

# %% [markdown]
# ## Increase NCX

# %%
caseNCX = empty()
caseNCX.caseName = "mouse_ncx1p25x_freq1p0_60" 
caseNCX.fileName = caseNCX.caseName+".pickle"
caseNCX.data = ao.readPickle(caseNCX.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNCX.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.9e3],
                          case1legend="Baseline",
                          case2legend="+NCX")
        plt.legend(bbox_to_anchor=(3.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/NCX_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %% [markdown]
# ## Plot diff_CaSR

# %%
names=['Baseline','+Amylin','+HIP','+LCC']

diff_CaSR=np.array([diffBaseline_CaSR, diffAmylin_CaSR, diffHIP_CaSR, diffLCC_CaSR])
print diff_CaSR

min_CaSR=np.array([minBaseline_CaSR, minAmylin_CaSR, minHIP_CaSR, minLCC_CaSR])
print min_CaSR

# %%
N = 1.

ind = np.arange(N)  # the x locations for the groups
width = 0.15  
width = 0.3

class empty:pass
baseline=empty()
baseline.names = names[::4]
baseline.diff = diff_CaSR[::4]
baseline.minima = min_CaSR[::4]

amylin=empty()
amylin.names = names[1::4]
amylin.diff = diff_CaSR[1::4]
amylin.minima = min_CaSR[1::4]

hip=empty()
hip.names = names[2::4]
hip.diff = diff_CaSR[2::4]
hip.minima = min_CaSR[2::4]

lcc=empty()
lcc.names = names[3::4]
lcc.diff = diff_CaSR[3::4]
lcc.minima = min_CaSR[3::4]

# %%
#fig, ax = plt.subplots(dpi=300,figsize=(15,6))
fig, ax = plt.subplots(dpi=600)
rects1a = ax.bar(ind, baseline.minima, width, color='b')
rects1b = ax.bar(ind, baseline.diff, width, color='r',bottom=baseline.minima)
rects2a = ax.bar(ind+width+0.2, amylin.minima, width, color='b')
rects2b = ax.bar(ind+width+0.2, amylin.diff, width, color='r',bottom=amylin.minima)
rects3a = ax.bar(ind+2*width+0.4, hip.minima, width, color='b')
rects3b = ax.bar(ind+2*width+0.4, hip.diff, width, color='r',bottom=hip.minima)
rects4a = ax.bar(ind+3*width+0.6, lcc.minima, width, color='b')
rects4b = ax.bar(ind+3*width+0.6, lcc.diff, width, color='r',bottom=lcc.minima)
#plt.plot((0.95, 0.95), (0, -620), 'k--')
         
ax.set_ylabel('[Ca_SR [mM]]',fontsize=20,weight="bold")
ax.legend( (rects1a[0],rects1b[0]),('Minima','Difference'), loc=4, fontsize=14) 

ax.set_xticks([ind,ind+width+0.2,ind+2*width+0.5,ind+3*width+0.7])
#ax.set_xticklabels( ('Baseline', 'SL Leak', '-SERCA/+Leak', '+LCC'), rotation=45,weight="bold" ,fontsize=12)
ax.set_xticklabels( ('Baseline', 'Amylin Incubation', '+HIP', '+LCC'), rotation=45,weight="bold" ,fontsize=12)
ax.set_ylim([0,0.65])
plt.tight_layout()
outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/CaSR_state.png"
plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)
#plt.gcf().savefig("/net/share/cesc235/pkh-lab-papers/150817_despa/figs/CaSR_MinMax.png")

# %%
max_y=np.array([maxBaseline_CaSR, max1p125_CaSR, max1p25_CaSR, max1p375_CaSR, max1p5_CaSR, max1p625_CaSR, max1p75_CaSR])
min_y=np.array([minBaseline_CaSR, min1p125_CaSR, min1p25_CaSR, min1p375_CaSR, min1p5_CaSR, min1p625_CaSR, min1p75_CaSR])
diff_y=np.array([diffBaseline_CaSR, diff1p125_CaSR, diff1p25_CaSR, diff1p375_CaSR, diff1p5_CaSR, diff1p625_CaSR, diff1p75_CaSR])
leak=np.linspace(1.0, 1.75, 7)
print leak

# %%
ax1 = plt.subplot(1,1,1)
ax1.plot(leak,min_y,label='Minimia')
ax1.plot(leak,max_y,label='Maximia')
ax1.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)

ax2 = ax1.twinx()
ax2.plot(leak,diff_y,'r*',label='Transient Height')
ax2.legend(bbox_to_anchor=(1.9,0.75),fancybox=True, shadow=True)

ax1.set_xlim([0.75,2.0])
ax1.set_ylim([0,0.75])
ax1.set_ylabel("Ca_SR [mM]",**font)
ax1.set_xlabel("Leak Rate",**font)
#ax1.set_title("Ca_SR")
ax2.set_ylabel("$\Delta$(Ca_SR) [mM]",**font)

outFile='/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/diff_CaSRConc.png'
plt.tight_layout()
plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
font = {'weight' : 'bold',
        'size'   : 10}
matplotlib.rc('font', **font)

# %% [markdown]
# ## Plot V

# %%
def Plot3PickleData(data1,data2=None,data3=None,idxName="V",ylabel="V (mV)",trange=None,
    case1legend = None, case2legend=None, case3legend=None,
    ):

  #  idx1=runner.model.state_indices(idxName)     
  # fluxes
  ms_to_s = 1e-3
  class empty:pass

  def mycont(data):
    datac = empty()
    datac.t = data['t'] * ms_to_s
    datac.s = data['s']
    datac.s_idx = data['s_idx']
    datac.j = data['j']
    datac.j_idx = data['j_idx']

    if idxName in datac.j_idx:
      datac.v = datac.j
      datac.v_idx = datac.j_idx
    # states 
    elif idxName in datac.s_idx:
      datac.v = datac.s
      datac.v_idx = datac.s_idx
    else:
      print idxName, " not found"
      datac.v =None

    return datac

  datac1 = mycont(data1)
  if data2!=None:
    datac2 = mycont(data2)
  if data3!=None:
    datac3 = mycont(data3)

  fig = plt.figure()

  if trange==None:
    fig.add_subplot(111)

  else:
    trange = np.asarray(trange)
    plt.subplot(1,2,2)
    if datac1.v !=None:
      idx1 = datac1.v_idx.index(idxName)
      plt.plot(datac1.t,datac1.v[:,idx1],'k',label=case1legend)
    if data2!=None and datac2.v !=None:
      idx2 = datac2.v_idx.index(idxName)
      plt.plot(datac2.t,datac2.v[:,idx2],'r',label=case2legend)
    if data3!=None and datac3.v !=None:
      idx3 = datac3.v_idx.index(idxName)
      plt.plot(datac3.t,datac3.v[:,idx3],'b',label=case3legend)
    plt.xlim(trange*ms_to_s)
#    plt.subplot(1,2,1)

#  if datac1.v !=None:
#    idx1 = datac1.v_idx.index(idxName)
#    plt.plot(datac1.t,datac1.v[:,idx1],'k',label=case1legend)
#  if data2!=None and datac2.v !=None:
#    idx2 = datac2.v_idx.index(idxName)
#    plt.plot(datac2.t,datac2.v[:,idx2],'r',label=case2legend)
#  if data3!=None and datac3.v !=None:
#    idx3 = datac3.v_idx.index(idxName)
#    plt.plot(datac3.t,datac3.v[:,idx3],'b',label=case3legend)
  plt.xlabel('time [s]')
  plt.ylabel(ylabel)
  plt.legend(loc=3)
  plt.tight_layout()

# %%
root="/net/share/shared/papers/despa/"
states = ["V"]
for i,state in enumerate(states):
        Plot3PickleData(caseExtended1Hz.data,data2=caseHIP.data,data3=caseAmylin1p25.data,idxName=state, 
                          ylabel=state,trange=[20.0e3,20.2e3],
                          case1legend="Baseline",
                          case2legend="+HIP",
                          case3legend="+Amylin")
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/V_state.png"
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai"]
for i,state in enumerate(states):
        Plot3PickleData(caseExtended1Hz.data,data2=caseHIP.data,data3=caseAmylin1p25.data,idxName=state, 
                          ylabel=state,trange=[20.0e3,20.5e3],
                          case1legend="Baseline",
                          case2legend="+HIP",
                          case3legend="+Amylin")
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()
        outFile="/net/share/shared/papers/despa/Cai_state.png"
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %% [markdown]
# ## Increase SERCA uptake

# %%
case_incrSERCA1p25 = empty()
case_incrSERCA1p25.caseName = "mouse_incrSERCAuptake1p25_freq1p0_60" 
case_incrSERCA1p25.fileName = case_incrSERCA1p25.caseName+".pickle"
case_incrSERCA1p25.data = ao.readPickle(case_incrSERCA1p25.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case_incrSERCA1p25.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case_incrSERCA1p25.caseName)
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)

# %%
case_incrSERCA1p50 = empty()
case_incrSERCA1p50.caseName = "mouse_incrSERCAuptake1p50_freq1p0_60" 
case_incrSERCA1p50.fileName = case_incrSERCA1p50.caseName+".pickle"
case_incrSERCA1p50.data = ao.readPickle(case_incrSERCA1p50.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case_incrSERCA1p50.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case_incrSERCA1p50.caseName)
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)

# %%
case_incrSERCA1p75 = empty()
case_incrSERCA1p75.caseName = "mouse_incrSERCAuptake1p75_freq1p0_60" 
case_incrSERCA1p75.fileName = case_incrSERCA1p75.caseName+".pickle"
case_incrSERCA1p75.data = ao.readPickle(case_incrSERCA1p75.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case_incrSERCA1p75.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case_incrSERCA1p75.caseName)
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)

# %%
case_incrSERCA2p00 = empty()
case_incrSERCA2p00.caseName = "mouse_incrSERCAuptake2p00_freq1p0_60" 
case_incrSERCA2p00.fileName = case_incrSERCA2p00.caseName+".pickle"
case_incrSERCA2p00.data = ao.readPickle(case_incrSERCA2p00.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case_incrSERCA2p00.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case_incrSERCA2p00.caseName)

# %% [markdown]
# ## Increase Ca2+ leak (Na+ is kept constant)

# %%
caseCaLeak1p10 = empty()
caseCaLeak1p10.caseName = "mouse_CaLeak1p10x_freq1p0_60" 
caseCaLeak1p10.fileName = caseCaLeak1p10.caseName+".pickle"
caseCaLeak1p10.data = ao.readPickle(caseCaLeak1p10.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseCaLeak1p10.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseCaLeak1p10.caseName)

# %%
caseCaLeak1p125 = empty()
caseCaLeak1p125.caseName = "mouse_CaLeak1p125x_freq1p0_60" 
caseCaLeak1p125.fileName = caseCaLeak1p125.caseName+".pickle"
caseCaLeak1p125.data = ao.readPickle(caseCaLeak1p125.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseCaLeak1p125.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend="Baseline",
                          case2legend="Increased Ca2+ leak by 12.5%")
        plt.legend(bbox_to_anchor=(1.2,1.0),fancybox=True, shadow=True)
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/CaLeak1p125_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
caseCaLeak1p25 = empty()
caseCaLeak1p25.caseName = "mouse_CaLeak1p25x_freq1p0_60" 
caseCaLeak1p25.fileName = caseCaLeak1p25.caseName+".pickle"
caseCaLeak1p25.data = ao.readPickle(caseCaLeak1p25.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseCaLeak1p25.data,idxName=state, 
                          ylabel=state,trange=[20e3,21.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseCaLeak1p25.caseName)

# %%
caseCaLeak1p375 = empty()
caseCaLeak1p375.caseName = "mouse_CaLeak1p375x_freq1p0_60" 
caseCaLeak1p375.fileName = caseCaLeak1p375.caseName+".pickle"
caseCaLeak1p375.data = ao.readPickle(caseCaLeak1p375.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseCaLeak1p375.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseCaLeak1p375.caseName)

# %%
caseCaLeak1p5 = empty()
caseCaLeak1p5.caseName = "mouse_CaLeak1p5x_freq1p0_60" 
caseCaLeak1p5.fileName = caseCaLeak1p5.caseName+".pickle"
caseCaLeak1p5.data = ao.readPickle(caseCaLeak1p5.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseCaLeak1p5.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseCaLeak1p5.caseName)

# %% [markdown]
# ## Increase Na+ leak (Ca2+ is kept constant)

# %%
caseNaLeak1p125 = empty()
caseNaLeak1p125.caseName = "mouse_NaLeak1p125x_freq1p0_60" 
caseNaLeak1p125.fileName = caseNaLeak1p125.caseName+".pickle"
caseNaLeak1p125.data = ao.readPickle(caseNaLeak1p125.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR","Nai"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNaLeak1p125.data,idxName=state, 
                          ylabel=state,trange=[50e3,50.5e3],
                          case1legend="Baseline",
                          case2legend="Increased Na+ Leak 12.5%")
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/NaLeak1p125_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
caseNaLeak1p25 = empty()
caseNaLeak1p25.caseName = "mouse_NaLeak1p25x_freq1p0_60" 
caseNaLeak1p25.fileName = caseNaLeak1p25.caseName+".pickle"
caseNaLeak1p25.data = ao.readPickle(caseNaLeak1p25.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNaLeak1p25.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseNaLeak1p25.caseName)

# %%
caseNaLeak1p375 = empty()
caseNaLeak1p375.caseName = "mouse_NaLeak1p375x_freq1p0_60" 
caseNaLeak1p375.fileName = caseNaLeak1p375.caseName+".pickle"
caseNaLeak1p375.data = ao.readPickle(caseNaLeak1p375.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNaLeak1p375.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseNaLeak1p375.caseName)

# %%
caseNaLeak1p5 = empty()
caseNaLeak1p5.caseName = "mouse_NaLeak1p5x_freq1p0_60" 
caseNaLeak1p5.fileName = caseNaLeak1p5.caseName+".pickle"
caseNaLeak1p5.data = ao.readPickle(caseNaLeak1p5.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNaLeak1p5.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline",
                          case2legend="Increased Na+ Leak 50%")
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/NaLeak1p5_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
caseNaLeak1p625 = empty()
caseNaLeak1p625.caseName = "mouse_NaLeak1p625x_freq1p0_60" 
caseNaLeak1p625.fileName = caseNaLeak1p625.caseName+".pickle"
caseNaLeak1p625.data = ao.readPickle(caseNaLeak1p625.fileName)

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=caseNaLeak1p625.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=caseNaLeak1p625.caseName)

# %% [markdown]
# ## Replicate Figure 5

# %% [markdown]
# #### Change frequencies

# %%
case0p1Hz = empty()
case0p1Hz.caseName = "mouse_freq0p1_60" 
case0p1Hz.fileName = case0p1Hz.caseName+".pickle"
case0p1Hz.data = ao.readPickle(case0p1Hz.fileName)
# Out:
# Reading mouse_freq0p1_60.pickle

# %%
s = case0p1Hz.data['s']
s_idx = case0p1Hz.data['s_idx']
idx = s_idx.index("Cai")

max0p1_Cai = np.amax(s[200e3:205e3,idx])
print max0p1_Cai
min0p1_Cai = np.amin(s[200e3:205e3,idx])
print min0p1_Cai
diff0p1_Cai=max0p1_Cai-min0p1_Cai
print diff0p1_Cai
# Out:
# 0.000989314473191
# 0.000116060032422
# 0.000873254440768

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case0p1Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case0p1Hz.caseName)
        plt.tight_layout()

# %%
case0p5Hz = empty()
case0p5Hz.caseName = "mouse_freq0p5_60" 
case0p5Hz.fileName = case0p5Hz.caseName+".pickle"
case0p5Hz.data = ao.readPickle(case0p5Hz.fileName)
# Out:
# Reading mouse_freq0p5_60.pickle

# %%
s = case0p5Hz.data['s']
s_idx = case0p5Hz.data['s_idx']
idx = s_idx.index("Cai")

max0p5_Cai = np.amax(s[200e3:205e3,idx])
print max0p5_Cai
min0p5_Cai = np.amin(s[200e3:205e3,idx])
print min0p5_Cai
diff0p5_Cai=max0p5_Cai-min0p5_Cai
print diff0p5_Cai
# Out:
# 0.000704839384679
# 0.000105571515722
# 0.000599267868957

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case0p5Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case0p5Hz.caseName)
                
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/Baseline0p5__%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
case1p5Hz = empty()
case1p5Hz.caseName = "mouse_freq1p5_60" 
case1p5Hz.fileName = case1p5Hz.caseName+".pickle"
case1p5Hz.data = ao.readPickle(case1p5Hz.fileName)
# Out:
# Reading mouse_freq1p5_60.pickle

# %%
s = case1p5Hz.data['s']
s_idx = case1p5Hz.data['s_idx']
idx = s_idx.index("Cai")

max1p5_Cai = np.amax(s[200e3:205e3,idx])
print max1p5_Cai
min1p5_Cai = np.amin(s[200e3:205e3,idx])
print min1p5_Cai
diff1p5_Cai=max1p5_Cai-min1p5_Cai
print diff1p5_Cai
# Out:
# 0.00053981644012
# 0.000106807422548
# 0.000433009017572

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case1p5Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend=caseExtended1Hz.caseName,
                          case2legend=case1p5Hz.caseName)

# %%
case2p0Hz = empty()
case2p0Hz.caseName = "mouse_freq2p0_60" 
case2p0Hz.fileName = case2p0Hz.caseName+".pickle"
case2p0Hz.data = ao.readPickle(case2p0Hz.fileName)
# Out:
# Reading mouse_freq2p0_60.pickle

# %%
s = case2p0Hz.data['s']
s_idx = case2p0Hz.data['s_idx']
idx = s_idx.index("Cai")

max2p0_Cai = np.amax(s[200e3:205e3,idx])
print max2p0_Cai
min2p0_Cai = np.amin(s[200e3:205e3,idx])
print min2p0_Cai
diff2p0_Cai=max2p0_Cai-min2p0_Cai
print diff2p0_Cai
# Out:
# 0.000553063162565
# 0.000119008065332
# 0.000434055097233

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(caseExtended1Hz.data,data2=case2p0Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline 1.0 Hz",
                          case2legend="Baseline 2.0 Hz")
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/Baseline2p__%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %% [markdown]
# ##### Increase leak

# %%
caseHIP0p1Hz = empty()
caseHIP0p1Hz.caseName = "mouse_decrSERCAuptake0p50_leak1p25x_freq0p1_60" 
caseHIP0p1Hz.fileName = caseHIP0p1Hz.caseName+".pickle"
caseHIP0p1Hz.data = ao.readPickle(caseHIP0p1Hz.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_leak1p25x_freq0p1_60.pickle

# %%
s = caseHIP0p1Hz.data['s']
s_idx = caseHIP0p1Hz.data['s_idx']
idx = s_idx.index("Cai")

max0p1HIP_Cai = np.amax(s[200e3:205e3,idx])
print max0p1HIP_Cai
min0p1HIP_Cai = np.amin(s[200e3:205e3,idx])
print min0p1HIP_Cai
diff0p1HIP_Cai=max0p1HIP_Cai-min0p1HIP_Cai
print diff0p1HIP_Cai
# Out:
# 0.00142310967368
# 0.000139820593701
# 0.00128328907998

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(case0p1Hz.data,data2=caseHIP0p1Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline 0.1Hz",
                          case2legend="+HIP 0.1Hz")

# %%
caseHIP0p5Hz = empty()
caseHIP0p5Hz.caseName = "mouse_decrSERCAuptake0p50_leak1p25x_freq0p5_60" 
caseHIP0p5Hz.fileName = caseHIP0p5Hz.caseName+".pickle"
caseHIP0p5Hz.data = ao.readPickle(caseHIP0p5Hz.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_leak1p25x_freq0p5_60.pickle

# %%
s = caseHIP0p5Hz.data['s']
s_idx = caseHIP0p5Hz.data['s_idx']
idx = s_idx.index("Cai")

max0p5HIP_Cai = np.amax(s[200e3:205e3,idx])
print max0p5HIP_Cai
min0p5HIP_Cai = np.amin(s[200e3:205e3,idx])
print min0p5HIP_Cai
diff0p5HIP_Cai=max0p5HIP_Cai-min0p5HIP_Cai
print diff0p5HIP_Cai
# Out:
# 0.000898849951963
# 0.000123934027346
# 0.000774915924617

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(case0p5Hz.data,data2=caseHIP0p5Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline 0.5Hz",
                          case2legend="+HIP 0.5Hz")
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/Baseline_HIP_0p5Hz_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
caseHIP1p5Hz = empty()
caseHIP1p5Hz.caseName = "mouse_decrSERCAuptake0p50_leak1p25x_freq1p5_60" 
caseHIP1p5Hz.fileName = caseHIP1p5Hz.caseName+".pickle"
caseHIP1p5Hz.data = ao.readPickle(caseHIP1p5Hz.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_leak1p25x_freq1p5_60.pickle

# %%
s = caseHIP1p5Hz.data['s']
s_idx = caseHIP1p5Hz.data['s_idx']
idx = s_idx.index("Cai")

max1p5HIP_Cai = np.amax(s[200e3:205e3,idx])
print max1p5HIP_Cai
min1p5HIP_Cai = np.amin(s[200e3:205e3,idx])
print min1p5HIP_Cai
diff1p5HIP_Cai=max1p5HIP_Cai-min1p5HIP_Cai
print diff1p5HIP_Cai
# Out:
# 0.000674996243817
# 0.000151364716249
# 0.000523631527568

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(case1p5Hz.data,data2=caseHIP1p5Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline 1.5Hz",
                          case2legend="+HIP 1.5Hz")

# %%
caseHIP2p0Hz = empty()
caseHIP2p0Hz.caseName = "mouse_decrSERCAuptake0p50_leak1p25x_freq2p0_60" 
caseHIP2p0Hz.fileName = caseHIP2p0Hz.caseName+".pickle"
caseHIP2p0Hz.data = ao.readPickle(caseHIP2p0Hz.fileName)
# Out:
# Reading mouse_decrSERCAuptake0p50_leak1p25x_freq2p0_60.pickle

# %%
s = caseHIP2p0Hz.data['s']
s_idx = caseHIP2p0Hz.data['s_idx']
idx = s_idx.index("Cai")

max2p0HIP_Cai = np.amax(s[200e3:205e3,idx])
print max2p0HIP_Cai
min2p0HIP_Cai = np.amin(s[200e3:205e3,idx])
print min2p0HIP_Cai
diff2p0HIP_Cai=max2p0HIP_Cai-min2p0HIP_Cai
print diff2p0HIP_Cai
# Out:
# 0.000728535470013
# 0.000188016015582
# 0.000540519454431

# %%
root="/net/share/shared/papers/despa/"
states = ["Cai","V","Ca_SR"]
for i,state in enumerate(states):
        ao.PlotPickleData(case2p0Hz.data,data2=caseHIP2p0Hz.data,idxName=state, 
                          ylabel=state,trange=[20e3,20.5e3],
                          case1legend="Baseline 2.0Hz",
                          case2legend="+HIP 2.0Hz")
        plt.tight_layout()    
        outFile="/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/Baseline_HIP_2p0Hz_%s.png"%state
        plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight',dpi=300)

# %%
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

# %%
ctl_y=np.array([diff0p1_Cai, diff0p5_Cai, diffBaseline_Cai, diff1p5_Cai, diff2p0_Cai])
ctl_miny=np.array([min0p1_Cai, min0p5_Cai, minBaseline_Cai, min1p5_Cai, min2p0_Cai])
pd_y=np.array([diff0p1HIP_Cai, diff0p5HIP_Cai, diffHIP_Cai, diff1p5HIP_Cai, diff2p0HIP_Cai])
pd_miny=np.array([min0p1HIP_Cai, min0p5HIP_Cai, minHIP_Cai, min1p5HIP_Cai, min2p0HIP_Cai])
freq=(0.1,0.5,1.0,1.5,2.0)

# %%
ax1 = plt.subplot(1,1,1)

#############

ax1.plot(freq,ctl_y/mM_to_uM,'k*-',linewidth=2.0,ms=8,label="Baseline")
ax1.plot(freq,pd_y/mM_to_uM,'r.-',linewidth=2.0,ms=8,label="+HIP")
ax1.legend(loc=0)
#ax1.set_title("Cai")
ax1.legend(loc=9)

mM_to_uM = 1e-3
ax2 = ax1.twinx()
ax2.plot(freq,ctl_miny/mM_to_uM,'k--',linewidth=2.0,ms=8,label="Min Baseline")
ax2.plot(freq,pd_miny/mM_to_uM,'r-.',linewidth=2.0,ms=8,label="Min +HIP")

plt.xlim(0,2.0)

plt.tight_layout()
ax1.set_ylabel("$\Delta$ Cai [uM]",weight="bold",fontsize=16)
ax2.set_ylabel("Diastolic Cai [uM]",weight="bold",fontsize=16)
ax1.set_xlabel("Frequency [Hz]",weight="bold",fontsize=16)
ax2.legend(loc=5)
plt.tight_layout()
plt.gcf().savefig('/net/share/cesc235/pkh-lab-papers/150817_despa/figs/mouse/mouse_figure5D.png',dpi=300)
