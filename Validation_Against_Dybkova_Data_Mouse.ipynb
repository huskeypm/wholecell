# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import analyzeODE as ao
import matplotlib.pyplot as plt
cases = dict()
class empty:pass
# Out:
# WARNING: ode idx is hardcoded

# %%
### out put to directory for despa paper
rootOutput = "/net/share/shared/papers/despa/Brad/"

# %%
refPx = [38,77] # reference pixel numbers
refSecNum = [1.0,400.0] # reference values corresponding to pixel numbers

#measuredHeight = 108. 
#refSecNm[1]/refPx[1] * measuredH
#measuredHalfMax = 159.
#refSecNm[0]/refPx[0] * measuredHalfMax

# %%
data = np.loadtxt("/home/AD/bdst227/ipython/ipython-notebooks/Despa/wholecell/despaJobs/Dybkova_data.txt",skiprows=3)

Pxl_time = data[:,0]
Pxl_Con = 288 - data[:,1]

print Pxl_time
print Pxl_Con

time_exp = (refSecNum[0]/refPx[0]) * Pxl_time  
concentration = (refSecNum[1]/refPx[1]) * Pxl_Con

print time
print concentration
# Out:
# [  73.   75.   76.   78.   79.   80.   81.   82.   83.   86.   90.   95.
#   104.  108.  109.]
# [  77.   77.  177.  171.  158.  134.  122.  117.  110.  100.   89.   81.
#    76.   75.   75.]
# [ 1.92105263  1.97368421  2.          2.05263158  2.07894737  2.10526316
#   2.13157895  2.15789474  2.18421053  2.26315789  2.36842105  2.5
#   2.73684211  2.84210526  2.86842105]
# [ 400.          400.          919.48051948  888.31168831  820.77922078
#   696.1038961   633.76623377  607.79220779  571.42857143  519.48051948
#   462.33766234  420.77922078  394.80519481  389.61038961  389.61038961]

# %%
root = "/net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/"
doReload=True

if doReload:

    caseBase1p0HzMouseSERCA40p00 = empty()
    cases["Basefreq1p0MouseSERCA40p00"] = caseBase1p0HzMouseSERCA40p00
    caseBase1p0HzMouseSERCA40p00.caseName = "mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA40p00pct_freq1p0Hz_cat" 
    caseBase1p0HzMouseSERCA40p00.name = root+caseBase1p0HzMouseSERCA40p00.caseName+".pkl"

ao.LoadPickles(cases,noOverwrite=True)
# Out:
# #  Basefreq1p0MouseSERCA40p00
# Loading /net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA40p00pct_freq1p0Hz_cat.pkl
# Reading /net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA40p00pct_freq1p0Hz_cat.pkl

# %%
root = "/net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/"
doReload=True

if doReload:

    caseBase1p0HzMouseSERCA50p00 = empty()
    cases["Basefreq1p0MouseSERCA50p00"] = caseBase1p0HzMouseSERCA50p00
    caseBase1p0HzMouseSERCA50p00.caseName = "mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA50p00pct_freq1p0Hz_cat" 
    caseBase1p0HzMouseSERCA50p00.name = root+caseBase1p0HzMouseSERCA50p00.caseName+".pkl"

ao.LoadPickles(cases,noOverwrite=True)
# Out:
# #  Basefreq1p0MouseSERCA50p00
# Loading /net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA50p00pct_freq1p0Hz_cat.pkl
# Reading /net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA50p00pct_freq1p0Hz_cat.pkl
# #
#  Basefreq1p0MouseSERCA40p00
# Loading /net/share/bdst227/Despa/Despa_Simulations_Data/mouse_Simulations/mouse_BASELINE_Temp_310p00_leak100p00pct_nka100p00pct_SERCA40p00pct_freq1p0Hz_cat.pkl
# Skipping read, since already populated

# %%
def shiftNnorm(ctl_0p5Hz):
    minCtl_Cai_exp0p5Hz = np.amin(ctl_0p5Hz)
    Ctl_Cai_shift0p5Hz =  ctl_0p5Hz -  minCtl_Cai_exp0p5Hz
    maxCtl_Cai_exp0p5Hz = np.amax(Ctl_Cai_shift0p5Hz)
    Ctl_Cai_shift0p5Hz/=maxCtl_Cai_exp0p5Hz
    
    return Ctl_Cai_shift0p5Hz

def normShizzle(case0p5Hz,tRange = [int(290e3),int(291e3)]):
    s = case0p5Hz.data['s']
    s_idx = case0p5Hz.data['s_idx']
    idx = s_idx.index("Cai")
    t = case0p5Hz.data['t']

    cais = s[tRange[0]:tRange[1],idx]
    min0p5Hz_Cai = np.amin(cais)
    #print minWT0p5Hz_Cai
    max0p5Hz_Cai = np.amax(cais)
    max0p5Hz_Caix = np.argmax(cais)
    print max0p5Hz_Caix

    Comp_Cai_shift0p5Hz = cais - min0p5Hz_Cai
    #print Comp_Cai_shift
    maxComp_Cai_shift0p5Hz = np.amax(Comp_Cai_shift0p5Hz)
    Comp_Cai_shift0p5Hz/=maxComp_Cai_shift0p5Hz
    #print Comp_Cai_shift

    ms_to_s = 1e-3
    time=t[tRange[0]:tRange[1]]*ms_to_s
    
    return time, Comp_Cai_shift0p5Hz

# %%
Ctl_Cai_shift = shiftNnorm(concentration)

case1p0HzSERCA40p00 = cases["Basefreq1p0MouseSERCA40p00"]
timeSERCA40p00, Comp_Cai_shift1p0HzSERCA40p00 = normShizzle(case1p0HzSERCA40p00)

case1p0HzSERCA50p00 = cases["Basefreq1p0MouseSERCA50p00"]
timeSERCA50p00, Comp_Cai_shift1p0HzSERCA50p00 = normShizzle(case1p0HzSERCA50p00)

plt.plot(timeSERCA40p00-290.1,Comp_Cai_shift1p0HzSERCA40p00,"r",label="Baseline/1.0Hz, SERCA40p00, T310")
plt.plot(timeSERCA50p00-290.1,Comp_Cai_shift1p0HzSERCA50p00,"b",label="Baseline/1.0Hz, SERCA50p00, T310")

plt.plot(time_exp-1.98,Ctl_Cai_shift,'--ok',label="Baseline/1.0Hz, Dybkova")

#plt.xlim(289.8,292.4)
#plt.ylim(0.0,1.1)

plt.ylabel("Normalized $\mathregular{[Ca]_i}$",fontsize=16,weight="bold")
plt.xlabel("Time [S]",fontsize=16,weight="bold")
plt.title("Comparing mouse \n model to Dybkova data", fontsize=16,weight="bold")

art = []
lgd = plt.legend(bbox_to_anchor=(1.752,1.035))
art.append(lgd)

outFile=rootOutput+"Dybkova_mouse_comparison.png"
plt.tight_layout()
plt.gcf().savefig(outFile,additional_artists=art,bbox_inches='tight',dpi=300)
# Out:
# 171
# 168

# %%
Ctl_Cai_shift = shiftNnorm(concentration)

case1p0HzSERCA40p00 = cases["Basefreq1p0MouseSERCA40p00"]
timeSERCA40p00, Comp_Cai_shift1p0HzSERCA40p00 = normShizzle(case1p0HzSERCA40p00)

case1p0HzSERCA50p00 = cases["Basefreq1p0MouseSERCA50p00"]
timeSERCA50p00, Comp_Cai_shift1p0HzSERCA50p00 = normShizzle(case1p0HzSERCA50p00)

#plt.plot(timeSERCA40p00-290.1,Comp_Cai_shift1p0HzSERCA40p00,"r",label="Baseline/1.0Hz, SERCA40p00, T310")
plt.plot(timeSERCA50p00-290.1,Comp_Cai_shift1p0HzSERCA50p00,"k",label="mouse fitted")

plt.plot(time_exp-1.98,Ctl_Cai_shift,'--om',label="Dybkova")

#plt.xlim(289.8,292.4)
plt.ylim(-0.1,1.1)

plt.ylabel("Normalized $\mathregular{[Ca]_i}$",fontsize=16,weight="bold")
plt.xlabel("Time [S]",fontsize=16,weight="bold")
plt.title("Comparing mouse \n model to Dybkova data", fontsize=16,weight="bold")

art = []
lgd = plt.legend(bbox_to_anchor=(1.37,1.03))
art.append(lgd)

outFile=rootOutput+"Dybkova_mouse_comparison.png"
plt.tight_layout()
plt.gcf().savefig(outFile,additional_artists=art,bbox_inches='tight',dpi=600)
# Out:
# 171
# 168

# %%
plt.plot(time,concentration)
