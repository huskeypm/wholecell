# %% [markdown]
# # Notebook for testing Despas' data of prediabetic leak

# %% [markdown]
# source configgotran.bash

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from runShannonTest import *

# %% [markdown]
# ### Load Readers, etc

# %%
import analyzeODE as ao
import numpy as np

# %%
# Despa 
T = 50* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,1.0] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,1.0]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=2000,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk2.00_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk2.00_G_NaBk2.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk2.00_G_NaBk3.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 3.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk3.00_G_NaBk1.00_stim2000 &
# ...

# %% [markdown]
# #### 1.0 Hz

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM],\
                                stim_period=1000)
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle

# %%
state="Nai"
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars,state=state,stim_period=1000)#,ylims=[1e-4*mM_to_uM,1.5e-3*mM_to_uM])
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle

# %% [markdown]
# # Compare Ca2+ transients and SR CA2+ transients as a function of increasing SL Ca/Na conductance

# %% [markdown]
# Uses data from previous section

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150609_"

if 1: 
  data3 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle")
  data4 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data3
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="Baseline")
#sca = s[1:,idxCaSR]  
#ax2.plot(t,sca,label="Baseline")
max1b = np.amax(sca3[40000:41000])
min1b = np.amin(sca3[40000:41000])

data = data4
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="2x Leak")
#sca = s[1:,idxCaSR]  
#ax2.plot(t,sca,label="2x Leak")
max1x = np.amax(sca4[40000:41000])
min1x = np.amin(sca4[40000:41000])

ax1.set_xlim([49000,50000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

#plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'leaks.png',dpi=300)

# %% [markdown]
# ### New parameters;
# time=50 s; stim_period=0.5

# %%
# Despa 
T = 50* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,1.0] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,1.0]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=500,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk2.00_G_NaBk1.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk2.00_G_NaBk2.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk2.00_G_NaBk3.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 50000 -var G_CaBk 3.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk3.00_G_NaBk1.00_stim500 &
# ...

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM],\
                                stim_period=500)
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim500.pickle

# %%
state="Nai"
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars,state=state,stim_period=500)#,ylims=[1e-4*mM_to_uM,1.5e-3*mM_to_uM])
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim500.pickle

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150615_"

if 1: 
  data1 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim500.pickle")
  data2 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim500.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim500.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim500.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")
#idxCaSR = runner.model.state_indices("Ca_SR")

data = data1
s = data['s']
t = data['t']
sca1 = s[1:,idxCai]  
ax1.plot(t,sca1,label="Baseline")

data = data2
s = data['s']
t = data['t']
sca2 = s[1:,idxCai]  
ax1.plot(t,sca2,label="3x Leak")

ax1.set_xlim([49500,50000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'leaks.png',dpi=300)

# %% [markdown]
# ### New parameters; time=50 s; stim_period=1.5

# %%
# Despa 
T = 50* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,1.0] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,1.0]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=1500,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk2.00_G_NaBk1.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk2.00_G_NaBk2.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk2.00_G_NaBk3.00_stim1500 &
# nohup python runShannonTest.py -stim 1500 -T 50000 -var G_CaBk 3.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk3.00_G_NaBk1.00_stim1500 &
# ...

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM],\
                                stim_period=1500)
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim1500.pickle

# %%
state="Nai"
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars,state=state,\
                                stim_period=1500)#,ylims=[1e-4*mM_to_uM,1.5e-3*mM_to_uM])
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim1500.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim1500.pickle

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150615_"

if 1: 
  data5 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim1500.pickle")
  data6 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim1500.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim1500.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim1500.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")
#idxCaSR = runner.model.state_indices("Ca_SR")

data = data5
s = data['s']
t = data['t']
sca5 = s[1:,idxCai]  
ax1.plot(t,sca5,label="Baseline")
max1_5b = np.amax(sca5[40000:41500])
min1_5b = np.amin(sca5[40000:41500])

data = data6
s = data['s']
t = data['t']
sca6 = s[1:,idxCai]  
ax1.plot(t,sca6,label="3x Leak")
max1_5x = np.amax(sca6[40000:41500])
min1_5x = np.amin(sca6[40000:41500])

ax1.set_xlim([40000,41500])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'leaks.png',dpi=300)

# %% [markdown]
# ### New parameters; time=50 s; stim_period=2.0

# %%
# Despa 
T = 50* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,1.0] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,1.0]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=2000,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk2.00_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk2.00_G_NaBk2.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk2.00_G_NaBk3.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 50000 -var G_CaBk 3.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk3.00_G_NaBk1.00_stim2000 &
# ...

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM],\
                                stim_period=2000)
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle

# %%
state="Nai"
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars,state=state,\
                                stim_period=2000)#,ylims=[1e-4*mM_to_uM,1.5e-3*mM_to_uM])
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk1.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk2.00_stim2000.pickle
# Reading ./run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150615_"

if 1: 
  data7 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle")
  data8 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")
#idxCaSR = runner.model.state_indices("Ca_SR")

data = data7
s = data['s']
t = data['t']
sca7 = s[1:,idxCai]  
ax1.plot(t,sca7,label="Baseline")

data = data8
s = data['s']
t = data['t']
sca8 = s[1:,idxCai]  
ax1.plot(t,sca8,label="3x Leak")

ax1.set_xlim([48000,50000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'leaks.png',dpi=300)

# %% [markdown]
# ### New parameters; time=50 s; stim_period=0.1

# %%
# Despa 
T = 50* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,1.0] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,1.0]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=100,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk2.00_G_NaBk1.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk2.00_G_NaBk2.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 2.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk2.00_G_NaBk3.00_stim100 &
# nohup python runShannonTest.py -stim 100 -T 50000 -var G_CaBk 3.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk3.00_G_NaBk1.00_stim100 &
# ...

# %% [markdown]
# ###### FIGURES

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data1
s = data['s']
t = data['t']
sca1 = s[1:,idxCai]  
ax1.plot(t,sca1,label="Baseline")
max0_5b = np.amax(sca1[40000:40500])
min0_5b = np.amin(sca1[40000:40500])

data = data2
s = data['s']
t = data['t']
sca2 = s[1:,idxCai]  
ax1.plot(t,sca2,label="3x Leak")
max0_5x = np.amax(sca2[40000:40500])
min0_5x = np.amin(sca2[40000:40500])

ax1.set_xlim([40000,40500])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data7
s = data['s']
t = data['t']
sca7 = s[1:,idxCai]  
ax1.plot(t,sca3,label="Baseline")
max2b = np.amax(sca7[40000:42000])
min2b = np.amin(sca7[40000:42000])

data = data8
s = data['s']
t = data['t']
sca8 = s[1:,idxCai]  
ax1.plot(t,sca4,label="3x Leak")
max2x = np.amax(sca8[40000:42000])
min2x = np.amin(sca8[40000:42000])

ax1.set_xlim([40000,42000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5B.png',dpi=300)

# %%
print np.shape(s[1:,idxCai])
print np.shape(s[:,:])
print np.shape(sca1)
print sca1[40000]
print np.amax(sca1[40000:40500])
print np.amax(sca2[40000:40500])
#print sca1[8000:8500]
print np.argmax(sca1[40000:40500])
print np.argmax(sca2[40000:40500])
# Out:
# (50000,)
# (50001, 39)
# (50000,)
# 0.000132584472264
# 0.000494242212189
# 0.000574435611935
# 146
# 145

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data1
s = data['s']
t = data['t']
sca1 = s[1:,idxCai]  
ax1.plot(t,sca1,label="Baseline, 0.5 Hz")

data = data2
s = data['s']
t = data['t']
sca2 = s[1:,idxCai]  
ax1.plot(t,sca2,label="3x Leak, 0.5 Hz")

data = data7
s = data['s']
t = data['t']
sca7 = s[1:,idxCai]  
ax1.plot(t,sca7,label="Baseline, 2 Hz")

data = data8
s = data['s']
t = data['t']
sca8 = s[1:,idxCai]  
ax1.plot(t,sca8,label="3x Leak, 2 Hz")

ax1.set_xlim([48000,50000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5AB.png',dpi=300)

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

min1 = np.amin(sca1[40000:40500])
sca1_shift = sca1[40000:40500]-min1
max1 = np.amax(sca1_shift)
sca1_shift/=max1

min2 = np.amin(sca2[40000:40500])
sca2_shift = sca2[40000:40500]-min2
max2 = np.amax(sca2_shift)
sca2_shift/=max2

ax1.plot(t[40000:40500],sca1_shift,label="Baseline, 0.5 Hz")
ax1.plot(t[40000:40500],sca2_shift,label="3x Leak, 0.5 Hz")

ax1.set_xlim([40000,40500])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

ax2 = plt.subplot(1,2,2)
#############

min3 = np.amin(sca3[40000:41000])
sca3_shift = sca3[40000:41000]-min3
max3 = np.amax(sca3_shift)
sca3_shift/=max3

min4 = np.amin(sca4[40000:41000])
sca4_shift = sca4[40000:41000]-min4
max4 = np.amax(sca4_shift)
sca4_shift/=max4

ax2.plot(t[40000:41000],sca3_shift,label="Baseline, 2 Hz")
ax2.plot(t[40000:41000],sca4_shift,label="3x Leak, 2 Hz")

ax2.set_xlim([40000,41000])
ax2.set_ylabel("Cai [mM]")
ax2.set_xlabel("t [ms]")
ax2.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5C.png',dpi=300)

# %%
diff0_5b = max0_5b-min0_5b
diff0_5x = max0_5x-min0_5x
diff1b = max1b-min1b
diff1x = max1x-min1x
diff1_5b = max1_5b-min1_5b
diff1_5x = max1_5x-min1_5x
diff2b = max2b-min2b
diff2x = max2x-min2x

print max0_5b, max1b, max1_5b, max2b
print min0_5b, min1b, min1_5b, min2b
print diff0_5b, diff1b, diff1_5b, diff2b

print max0_5x, max1x, max1_5x, max2x
print min0_5x, min1x, min1_5x, min2x
print diff0_5x, diff1x, diff1_5x, diff2x

ctl_y=np.array([diff0_5b, diff1b, diff1_5b, diff2b])
pd_y=np.array([diff0_5x, diff1x, diff1_5x, diff2x])
freq=np.arange(0.5,2.5,0.5)
# Out:
# 0.000494242212189 0.000315309037671 0.00033725719338 0.000315309037671
# 0.000114559444319 8.07676996126e-05 8.24816506415e-05 8.0761706563e-05
# 0.00037968276787 0.000234541338059 0.000254775542739 0.000234547331108
# 0.000574435611935 0.000471731851856 0.00046846196109 0.000471731851856
# 0.000120246306737 8.98513459641e-05 9.01691862242e-05 8.89381460774e-05
# 0.000454189305198 0.000381880505892 0.000378292774866 0.000382793705778

# %%
ax1 = plt.subplot(1,2,1)

#############

ax1.plot(freq,ctl_y,label="Baseline")

ax1.plot(freq,pd_y,label="3x Leak")

ax1.set_xlim([0,2.5])
ax1.set_ylabel("Difference in Cai [mM]")
ax1.set_xlabel("Frequency [Hz]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5D.png',dpi=300)
