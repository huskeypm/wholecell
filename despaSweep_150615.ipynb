# %% [markdown]
# # Notebook for testing Despas' data of prediabetic leak

# %% [markdown]
# source configgotran.bash

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from runShannonTest import *
# Out:
# WARNING: ode idx is hardcoded

# %% [markdown]
# ### Load Readers, etc

# %%
import analyzeODE as ao
import numpy as np

# %%
# Despa 
T = 100* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,2.75,0.25] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,2.75,0.25]
names,allKeys,allVars = GenSweptParams(varDict,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 1.250000 -name ./run_G_CaBk1.00_G_NaBk1.25_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 1.500000 -name ./run_G_CaBk1.00_G_NaBk1.50_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 1.750000 -name ./run_G_CaBk1.00_G_NaBk1.75_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 2.250000 -name ./run_G_CaBk1.00_G_NaBk2.25_stim1000 &
# nohup python runShannonTest.py -stim 1000 -T 100000 -var G_CaBk 1.000000 -var G_NaBk 2.500000 -name ./run_G_CaBk1.00_G_NaBk2.50_stim1000 &
# ...

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM])

# %%
state="Nai"
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars,state=state)#,ylims=[1e-4*mM_to_uM,1.5e-3*mM_to_uM])
# Out:
# Reading ./run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle
# ./run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle was not found. Skipping
# Reading ./run_G_CaBk1.00_G_NaBk1.50_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk2.50_stim1000.pickle
# Reading ./run_G_CaBk1.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk1.50_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk1.50_G_NaBk1.50_stim1000.pickle
# Reading ./run_G_CaBk1.50_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk1.50_G_NaBk2.50_stim1000.pickle
# Reading ./run_G_CaBk1.50_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk1.50_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.00_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk2.50_stim1000.pickle
# Reading ./run_G_CaBk2.00_G_NaBk3.00_stim1000.pickle
# Reading ./run_G_CaBk2.50_G_NaBk1.00_stim1000.pickle

# %% [markdown]
# # Compare Ca2+ transients and SR CA2+ transients as a function of increasing SL Ca/Na conductance

# %% [markdown]
# Uses data from previous section

# %%
root = "/home/AD/cesc235/wholecell_new2/wholecell/"
#versionPrefix = "150609_"

if 1: 
  data1 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle")
  data2 = ao.readPickle(root+"run_G_CaBk2.00_G_NaBk2.00_stim1000.pickle")

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data1
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="Baseline")
sca = s[1:,idxCaSR]  
ax2.plot(t,sca,label="Baseline")

data = data2
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="2x Leak")
sca = s[1:,idxCaSR]  
ax2.plot(t,sca,label="2x Leak")

ax1.set_xlim([8000,9000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

#plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'leaks.png',dpi=300)

# %% [markdown]
# ### New parameters;
# time=10 s; stim_period=0.5

# %%
# Despa 
T = 10* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,0.5] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,0.5]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=500,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 1.500000 -name ./run_G_CaBk1.00_G_NaBk1.50_stim500 &
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 2.500000 -name ./run_G_CaBk1.00_G_NaBk2.50_stim500 &
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim500 &
# nohup python runShannonTest.py -stim 500 -T 10000 -var G_CaBk 1.500000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.50_G_NaBk1.00_stim500 &
# Reading ./run_G_CaBk2.50_G_NaBk1.50_stim500.pickle
# Reading ./run_G_CaBk2.50_G_NaBk2.00_stim500.pickle
# ...

# %%
root = "/home/AD/cesc235/wholecell_new2/wholecell/"
versionPrefix = "150615_"

if 1: 
  data1 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim500.pickle")
  data2 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim500.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new2/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim500.pickle
# Reading /home/AD/cesc235/wholecell_new2/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim500.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")
idxCaSR = runner.model.state_indices("Ca_SR")

data = data1
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="Baseline")

data = data2
s = data['s']
t = data['t']
sca = s[1:,idxCai]  
ax1.plot(t,sca,label="3x Leak")

ax1.set_xlim([8000,8500])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)

# %%
# Despa 
T = 10* 1e3 # 300s --> ms
varDict = dict()  
varDict["G_CaBk"] = [1.0,3.00,0.5] # define 'fold' range over which G_CaBk is varied: (v[0]..v[1] in increments of v[2])
varDict["G_NaBk"] = [1.0,3.00,0.5]
names,allKeys,allVars = GenSweptParams(varDict,stim_period=2000,T=T)
len(names)
# Out:
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.00_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 1.500000 -name ./run_G_CaBk1.00_G_NaBk1.50_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 2.000000 -name ./run_G_CaBk1.00_G_NaBk2.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 2.500000 -name ./run_G_CaBk1.00_G_NaBk2.50_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.000000 -var G_NaBk 3.000000 -name ./run_G_CaBk1.00_G_NaBk3.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.500000 -var G_NaBk 1.000000 -name ./run_G_CaBk1.50_G_NaBk1.00_stim2000 &
# nohup python runShannonTest.py -stim 2000 -T 10000 -var G_CaBk 1.500000 -var G_NaBk 1.500000 -name ./run_G_CaBk1.50_G_NaBk1.50_stim2000 &
# ...

# %%
state="Cai"
class empty:pass
mM_to_uM = 1e3
ms_to_s = 1e-3
oMin,oMax=ao.ProcessTwoDOutputs(allKeys,allVars ,state=state,ylims=[1e-4*mM_to_uM,1.0e-3*mM_to_uM],stim_period=2000)
  data3 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle")
  data4 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new2/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle
# Reading /home/AD/cesc235/wholecell_new2/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data1
s = data['s']
t = data['t']
sca1 = s[1:,idxCai]  
ax1.plot(t,sca1,label="Baseline, 0.5 Hz")

data = data2
s = data['s']
t = data['t']
sca2 = s[1:,idxCai]  
ax1.plot(t,sca2,label="3x Leak, 0.5 Hz")

data = data3
s = data['s']
t = data['t']
sca3 = s[1:,idxCai]  
ax1.plot(t,sca3,label="Baseline, 2 Hz")

data = data4
s = data['s']
t = data['t']
sca4 = s[1:,idxCai]  
ax1.plot(t,sca4,label="3x Leak, 2 Hz")

ax1.set_xlim([6000,10000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5AB.png',dpi=300)

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data3
s = data['s']
t = data['t']
sca3 = s[1:,idxCai]  
ax1.plot(t,sca3,label="Baseline")
print sca3[8000]

data = data4
s = data['s']
t = data['t']
sca4 = s[1:,idxCai]  
ax1.plot(t,sca4,label="3x Leak")
print sca4[8000]

ax1.set_xlim([8000,10000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5B.png',dpi=300)
# Out:
# 8.0634742013e-05
# 8.90567645896e-05

# %%
print np.shape(s[1:,idxCai])
print np.shape(s[:,:])
print np.shape(sca)
print sca1[8000]
print np.amax(sca1[8000:8500])
print np.amax(sca2[8000:8500])
#print sca1[8000:8500]
print np.argmax(sca1[8000:8500])
print np.argmax(sca2[8000:8500])
# Out:
# (10000,)
# (10001, 39)
# (10000,)
# 0.000134968370253
# 0.000495198165636
# 0.000495198165636
# 146
# 145

# %%
ax1 = plt.subplot(1,2,1)

#############
idxCai = runner.model.state_indices("Cai")

baseline_shift = sca2[8000]-sca1[8000]
print baseline_shift

sca2_shift=sca2-baseline_shift
max_shift=np.amax(sca2_shift[8000:8500])/np.amax(sca1[8000:8500])

sca2_shift/=max_shift
ax1.plot(t,sca1,label="Baseline")
ax1.plot(t,sca2_shift,label="3x Leak")

ax1.set_xlim([8000,8500])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5C.png',dpi=300)
# Out:
# 1.03467473455e-05
