# %%
## Testing a few ODE operations

1. running gotranJIT with default parameters for quickly validating approaches [different pacings] DONE
2. comparing results with runShannonTest/jit
# Out:
#   File "<ipython-input-23-a6b7dee2593d>", line 3
#     1. running gotranJIT with default parameters for quickly validating approaches [different pacings] DONE
#              ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### GotranJIT.py
# gotranJIT.py allows you to quickly test your ode model, but won't offer much functionality for changing parameters, etc. '-doit' needs to be the last argument in your command string.
#
# <code>
# source configgotran.bash
# python gotranJIT.py -file_name shannon_2004_mouseIto.ode -stim_period 1000 -doit
# </code>
#
# I've verified that the model runs for different pacings (1-2 Hz). If you want to modify anything else, look at the code.

# %% [markdown]
# #### Test w mousified model

# %%
import gotranJIT
file_name = "shannon_2004_mouseIto.ode"
stateName = "V" # Cai
gotranJIT.doit(file_name = file_name,
               stateName=stateName,
               stim_period = 500 ) # [ms]
# Out:
# Using ode model  shannon_2004_mouseIto.ode
# Writing results to  results.txt
# Loaded ODE model 'shannon_2004_mouseIto' with:
# INFO:ModelParameters:Loaded ODE model 'shannon_2004_mouseIto' with:
#      Num full states: 39
# INFO:ModelParameters:     Num full states: 39
#       Num parameters: 124
# INFO:ModelParameters:      Num parameters: 124

# %%
gotranJIT.plotit()
# Out:
# Printing test.png

# %% [markdown]
# ### runShannonTest.py
# For parameter sweeps, pickle generation etc

# %% [markdown]
# #### Default shannon_2004.ode
# python runShannonTest.py -stim 1000 -jit -T 30000 -var PCa 0.001080 -var lccCaInact 5.950000 -name test_incrLCC_1000.pickle &

# %%
import analyzeODE as ao
# Out:
# WARNING: ode idx is hardcoded

# %%
data = ao.readPickle("test_incrLCC_1000.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])
# Out:
# Reading test_incrLCC_1000.pickle
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-4-c863a413a07e> in <module>()
# ----> 1 data = ao.readPickle("test_incrLCC_1000.pickle")
#       2
#       3 ms_to_s = 1e-3
#       4 si = data['s']
#       5 s_idx = data['s_idx']
#
# /home/AD/cesc235/wholecell_new3/asdf/wholecell/analyzeODE.pyc in readPickle(name)
#      19 def readPickle(name = "PCa0.75kss0.25.pickle"):
#      20   print "Reading " + name
# ---> 21   pkl_file = open(name, 'rb')
#      22   data1 = pickle.load(pkl_file)
#      23   pkl_file.close()
#
# IOError: [Errno 2] No such file or directory: 'test_incrLCC_1000.pickle'

# %% [markdown]
# #### shannon_2004_mouseIto.ode
# python runShannonTest.py -stim 1000 -jit -T 30000  -odeName shannon_2004_mouseIto.ode  -name mouse.pickle

# %%
data = ao.readPickle("rabbit.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "rabbit"
plt.gcf().savefig(title+".png")
# Out:
# Reading rabbit.pickle

# %%
data = ao.readPickle("mouseIto-Ikslow-Iss.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouseIto-Ikslow-Iss"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouseIto-Ikslow-Iss.pickle

# %%
data = ao.readPickle("mouseIK_serca.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouseIK_serca"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouseIK_serca.pickle

# %%
data = ao.readPickle("mouseIK_serca_ryr.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouseIK_serca_ryr"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouseIK_serca_ryr.pickle

# %%
data = ao.readPickle("mouseIK_serca_ryr_ncx.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouseIK_serca_ryr_ncx"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouseIK_serca_ryr_ncx.pickle

# %%
data = ao.readPickle("mouseIK_serca_ryr_ncx_ltcc.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
plt.ylim([9.03e-5,9.06e-5])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouseIK_serca_ryr_ncx_ltcc"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouseIK_serca_ryr_ncx_ltcc.pickle

# %%
import analyzeODE as ao
data = ao.readPickle("/home/AD/cesc235/wholecell_new3/asdf/wholecell/mouseIK_serca_ryr_ncx_ltcc.pickle")
ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
#plt.ylim([9.03e-5,9.06e-5])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouse"
plt.gcf().savefig(title+".png")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/asdf/wholecell/mouseIK_serca_ryr_ncx_ltcc.pickle

# %%
data = ao.readPickle("mouse.pickle")

ms_to_s = 1e-3
si = data['s']
s_idx = data['s_idx']
t = data['t'] * ms_to_s

# ca 
subplot(2,2,1)
label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,3)
plt.plot(t,si[:,idx])
#plt.ylim([9.03e-5,9.06e-5])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

# V
subplot(2,2,2)
label = "V"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
plt.title(label)

subplot(2,2,4)
plt.plot(t,si[:,idx])
plt.xlim([25e3*ms_to_s,30e3*ms_to_s])

title = "mouse-long"
plt.gcf().savefig(title+".png")
# Out:
# Reading mouse.pickle

# %% [markdown]
# ### More examples

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import analyzeODE as ao
data = ao.readPickle("/home/AD/cesc235/wholecell_new3/asdf/wholecell/rabbit.pickle")
# temporary, but files will work withouth this hack once the jobs are rerun
v = np.transpose(data['j'])
data['j'] = v
# Out:
# Reading /home/AD/cesc235/wholecell_new3/asdf/wholecell/rabbit.pickle

# %%
states = ["V", "Cai", "Nai"]
for i,state in enumerate(states):
    ao.PlotPickleData(data,idxName=state, label1=state,trange=[25e3,25.3e3])
    plt.tight_layout()
    title = "rabbit_gotranJIT_mouseEx"+state
    plt.gcf().savefig(title+".png")
fluxes = ["i_Na", "i_tof", "i_Kr"]
for i,flux in enumerate(fluxes):
    ao.PlotPickleData(data,idxName=flux,label1="%s [A/F]"%flux,trange=[25.1e3,25.4e3]) 
    title = "rabbit_gotranJIT_mouseEx"+flux
    plt.gcf().savefig(title+".png")

# %%
fluxes = ["i_tof", "i_Kr"]  # add the rest of the contributors here 

t = data['t']
iK = np.zeros(np.shape(t)[0])

j = data['j']
j_idx = data['j_idx']
for i,flux in enumerate(fluxes):
    idx1 = j_idx.index(flux)
    iK+=j[:,idx1]
    
plt.plot(t,iK,label="IK [A/F]")
plt.legend()

# %%
import analyzeODE as ao
data = ao.readPickle("/home/AD/cesc235/wholecell_new3/asdf/wholecell/mouseIK_serca_ryr_ncx_ltcc.pickle")
# temporary, but files will work withouth this hack once the jobs are rerun
v = np.transpose(data['j'])
data['j'] = v
# Out:
# Reading /home/AD/cesc235/wholecell_new3/asdf/wholecell/mouseIK_serca_ryr_ncx_ltcc.pickle

# %%
states = ["V", "Cai", "Nai"]
for i,state in enumerate(states):
    ao.PlotPickleData(data,idxName=state, label1=state,trange=[25e3,25.3e3])
    title = "mouseIK_serca_ryr_ncx_ltcc_gotranJIT_mouseEx"+state
    plt.gcf().savefig(title+".png")
    
fluxes = ["i_Na", "i_tof", "i_Kr"]
for i,flux in enumerate(fluxes):
    ao.PlotPickleData(data,idxName=flux,label1="%s [A/F]"%flux,trange=[25.1e3,25.4e3]) 
    title = "mouseIK_serca_ryr_ncx_ltcc_gotranJIT_mouseEx"+flux
    plt.gcf().savefig(title+".png")

# %% [markdown]
# $I_K$ is the sum over several potassium currents, so extra work is needed

# %%
fluxes = ["i_tof", "i_Kr"]  # add the rest of the contributors here 

t = data['t']
iK = np.zeros(np.shape(t)[0])

j = data['j']
j_idx = data['j_idx']
for i,flux in enumerate(fluxes):
    idx1 = j_idx.index(flux)
    iK+=j[:,idx1]
    
plt.plot(t,iK,label="IK [A/F]")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-14-60c71efb1bcc> in <module>()
#       8 for i,flux in enumerate(fluxes):
#       9     idx1 = j_idx.index(flux)
# ---> 10     iK+=j[:,idx1]
#      11
#      12 plt.plot(t,iK,label="IK [A/F]")
#
# ValueError: operands could not be broadcast together with shapes (30001,) (139,) (30001,)

# %%
import analyzeODE as ao
data = ao.readPickle("/home/AD/cesc235/wholecell_new3/asdf/wholecell/mouse_151120.pickle")
# temporary, but files will work withouth this hack once the jobs are rerun
v = np.transpose(data['j'])
data['j'] = v
# Out:
# Reading /home/AD/cesc235/wholecell_new3/asdf/wholecell/mouse_151120.pickle

# %%
states = ["V", "Cai", "Nai"]
for i,state in enumerate(states):
    ao.PlotPickleData(data,idxName=state, label1=state,trange=[25e3,25.5e3])
    title = "mouse_gotranJIT_mouseEx"+state
    plt.gcf().savefig(title+".png")

fluxes = ["i_Na", "i_tof", "i_Kr"]
for i,flux in enumerate(fluxes):
    ao.PlotPickleData(data,idxName=flux,label1="%s [A/F]"%flux,trange=[25.2e3,25.5e3]) 
    title = "mouse_gotranJIT_mouseEx"+flux
    plt.gcf().savefig(title+".png")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1fee47d9c239> in <module>()
#       7 fluxes = ["i_Na", "i_tof", "i_Kr"]
#       8 for i,flux in enumerate(fluxes):
# ----> 9     ao.PlotPickleData(data,idxName=flux,label1="%s [A/F]"%flux,trange=[25.2e3,25.5e3])
#      10     title = "mouse_gotranJIT_mouseEx"+flux
#      11     plt.gcf().savefig(title+".png")
#
# /home/AD/cesc235/wholecell_new3/asdf/wholecell/analyzeODE.pyc in PlotPickleData(data, idxName, label1, trange)
#     200     trange = np.asarray(trange)
#     201     plt.subplot(1,2,2)
# --> 202     plt.plot(t,v[:,idx1],'k',label=label1)
#     203     plt.xlim(trange*ms_to_s)
#     204     plt.subplot(1,2,1)
#
# /usr/lib/python2.7/dist-packages/matplotlib/pyplot.pyc in plot(*args, **kwargs)
#    3097         ax.hold(hold)
#    3098     try:
# -> 3099         ret = ax.plot(*args, **kwargs)
# ...

# %%
fluxes = ["i_tof", "i_Kr"]  # add the rest of the contributors here 

t = data['t']
iK = np.zeros(np.shape(t)[0])

j = data['j']
j_idx = data['j_idx']
for i,flux in enumerate(fluxes):
    idx1 = j_idx.index(flux)
    iK+=j[:,idx1]
    
plt.plot(t,iK,label="IK [A/F]")
plt.legend()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-60c71efb1bcc> in <module>()
#       8 for i,flux in enumerate(fluxes):
#       9     idx1 = j_idx.index(flux)
# ---> 10     iK+=j[:,idx1]
#      11
#      12 plt.plot(t,iK,label="IK [A/F]")
#
# ValueError: operands could not be broadcast together with shapes (30001,) (139,) (30001,)
