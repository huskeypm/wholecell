# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Extended runs
# Here we will 'daisy-chain' the simulations

# %%
import gotranJIT
from gotran.model.loadmodel import load_ode

# %%
import analyzeODE as ao
import numpy as np
#data = ao.readPickle("test_incrLCC_1000.pickle")

# %%
from runShannonTest import *

# %%
import gotranUtil as gU
gU.PrintStates()
gU.PrintParams()
# Out:
# Loaded ODE model 'shannon_2004' with:
# INFO:ModelParameters:Loaded ODE model 'shannon_2004' with:
#      Num full states: 39
# INFO:ModelParameters:     Num full states: 39
#       Num parameters: 124
# INFO:ModelParameters:      Num parameters: 124
# h 0.9867005
# j 0.991562
# m 0.001405627
# Xr 0.008641386
# Xs 0.005412034
# X_tos 0.004051574
# Y_tos 0.9945511
# R_tos 0.9946
# X_tof 0.004051574
# Y_tof 0.9945511
# d 7.175662e-06
# f 1.000681
# fCaB_SL 0.01452605
# fCaB_jct1 0.02421991
# R 0.8884332
# O 8.156628e-07
# I 1.024274e-07
# Ca_TroponinC 0.008773191
# Ca_TroponinC_Ca_Mg 0.1078283
# Mg_TroponinC_Ca_Mg 0.01524002
# Ca_Calmodulin 0.0002911916
# Ca_Myosin 0.001298754
# Mg_Myosin 0.1381982
# Ca_SRB 0.002143165
# Na_jct1_buf 3.539892
# Na_SL_buf 0.7720854
# Na_jct1 8.80329
# Na_SL 8.80733
# Nai 8.80853
# Ca_Calsequestrin 1.242988
# Ca_SLB_SL 0.1110363
# Ca_SLB_jct1 0.009566355
# Ca_SLHigh_SL 0.07297378
# Ca_SLHigh_jct1 0.007347888
# Ca_SR 0.5545201
# Ca_jct1 0.0001737475
# Ca_SL 0.0001031812
# Cai 8.597401e-05
# V -85.56885
# Loaded ODE model 'shannon_2004' with:
# INFO:ModelParameters:Loaded ODE model 'shannon_2004' with:
#      Num full states: 39
# INFO:ModelParameters:     Num full states: 39
#       Num parameters: 124
# INFO:ModelParameters:      Num parameters: 124
# Cao 1.8
# Cli 15
# Clo 150
# Cm 1.381e-10
# F 96485
# Ki 135
# Ko 5.4
# Mgi 1
# Nao 140
# Rgas 8314.3
# T 310
# cell_length 100
# cell_radius 10.25
# Fx_Na_SL 0.89
# Fx_Na_jct1 0.11
# G_INa 16
# Fx_NaBk_SL 0.89
# Fx_NaBk_jct1 0.11
# G_NaBk 0.000297
# Fx_NaK_SL 0.89
# Fx_NaK_jct1 0.11
# H_NaK 4
# I_NaK_max 1.90719
# Km_Ko 1.5
# Km_Nai 11
# Fx_Ks_SL 0.89
# Fx_Ks_jct1 0.11
# pKNa 0.01833
# g_Kp 0.001
# G_tos 0.06
# G_tof 0.02
# Fx_Cl_SL 0.89
# Fx_Cl_jct1 0.11
# G_Cl 0.109625
# Kd_ClCa 0.1
# G_ClBk 0.009
# Fx_ICaL_SL 0.1
# Fx_ICaL_jct1 0.9
# PCa 0.00054
# PK 2.7e-07
# PNa 1.5e-08
# Q10_CaL 1.8
# gamma_Cai 0.341
# gamma_Cao 0.341
# gamma_Ki 0.75
# gamma_Ko 0.75
# gamma_Nai 0.75
# gamma_Nao 0.75
# lccCaInact 1.7
# Fx_NCX_SL 0.89
# Fx_NCX_jct1 0.11
# HNa 3
# K_mCai 0.00359
# K_mCao 1.3
# K_mNai 12.29
# K_mNao 87.5
# Kd_act 0.000256
# Q10_NCX 1.57
# V_max_INaCa 9
# eta 0.35
# ksat 0.27
# Fx_SLCaP_SL 0.89
# Fx_SLCaP_jct1 0.11
# H_ICap 1.6
# Km 0.0005
# Q10_SLCaP 2.35
# V_maxAF 0.0673
# Fx_CaBk_SL 0.89
# Fx_CaBk_jct1 0.11
# G_CaBk 0.0002513
# EC50_SR 0.45
# HSR 2.5
# Max_SR 15
# Min_SR 1
# kiCa 0.5
# kim 0.005
# koCa 10
# kom 0.06
# ks 25
# KSRleak 5.348e-06
# H_Jpump 1.787
# Kmf 0.000246
# Kmr 1.7
# Q10_SRCaP 2.6
# V_max_Jpump 0.0053114
# Bmax_Calsequestrin 0.14
# Bmax_SLB_SL 0.0374
# Bmax_SLB_jct1 0.0046
# Bmax_SLHigh_SL 0.0134
# Bmax_SLHigh_jct1 0.00165
# koff_Calsequestrin 65
# koff_SLB 1.3
# koff_SLHigh 0.03
# kon_Calsequestrin 100
# kon_SL 100
# Bmax_Calmodulin 0.024
# Bmax_Myosin_Ca 0.14
# Bmax_Myosin_Mg 0.14
# Bmax_SRB 0.0171
# Bmax_TroponinC 0.07
# Bmax_TroponinC_Ca_Mg_Ca 0.14
# Bmax_TroponinC_Ca_Mg_Mg 0.14
# koff_Calmodulin 0.238
# koff_Myosin_Ca 0.00046
# koff_Myosin_Mg 5.7e-05
# koff_SRB 0.06
# koff_TroponinC 0.0196
# koff_TroponinC_Ca_Mg_Ca 3.2e-05
# koff_TroponinC_Ca_Mg_Mg 0.00333
# kon_Calmodulin 34
# kon_Myosin_Ca 13.8
# kon_Myosin_Mg 0.0157
# kon_SRB 100
# kon_TroponinC 32.7
# kon_TroponinC_Ca_Mg_Ca 2.37
# kon_TroponinC_Ca_Mg_Mg 0.003
# Bmax_SL 1.65
# Bmax_jct1 7.561
# koff 0.001
# kon 0.0001
# stim_amplitude 9.5
# stim_duration 5
# stim_period 1000
# stim_start 100

# %%
font = {'weight' : 'bold',
        'size'   : 12}
matplotlib.rc('font', **font)

# %% [markdown]
# #### Print all states/values

# %% [markdown]
# ## Decrease SERCA uptake¶

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    uptake = 0.5
    leak=3
    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_Jpump %f " % (0.0053114), # baseline
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case

    tag="decrSERCAuptake%3.1f_freq%3.1f"%(uptake,freq_Hz)
    label="uptake (-%3.1fx)"%uptake
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_Jpump %f " % (0.0053114*uptake), # baseline \
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case

#    tag="decrSERCAuptake%3.1f_leak%3.1f_freq%3.1f"%(uptake,leak,freq_Hz)
#    label="uptake (-%3.1fx)"%uptake
#    name = root+"despa_%s.pickle"%(tag) # filename 
#    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
#      "-var stim_period %f" % stim_period,
#      "-var V_max_Jpump %f " % (0.0053114*uptake), # 50% of uptake 
#      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
#      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
#      ]
#    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
#    caseDict[tag] = case
    
    tag="incrleak%3.1f_freq%3.1f"%(leak,freq_Hz)
    label="+HIP (%3.1fx)"%leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [0.1,0.5,1.0,1.5,2.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  baseline_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.5.pickle  &
# #  incrleak3.0_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq0.5.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &
# #  incrleak3.0_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq0.1.pickle  &
# #  baseline_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.1.pickle  &
# #  incrleak3.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq1.0.pickle  &
# #  baseline_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.5.pickle  &
# #  incrleak3.0_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq1.5.pickle  &
# #  decrSERCAuptake0.5_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var V_max_Jpump 0.002656  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_freq0.5.pickle  &
# #  decrSERCAuptake0.5_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var V_max_Jpump 0.002656  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_freq1.5.pickle  &
# #  incrleak3.0_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq2.0.pickle  &
# #  decrSERCAuptake0.5_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var V_max_Jpump 0.002656  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_freq0.1.pickle  &
# #  decrSERCAuptake0.5_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_Jpump 0.002656  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_freq1.0.pickle  &
# #  decrSERCAuptake0.5_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var V_max_Jpump 0.002656  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_freq2.0.pickle  &
# #  baseline_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq2.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  baseline_freq1.5 ./despa_baseline_freq1.5_5.pickle
# Reading ./despa_baseline_freq1.5_5.pickle
# #
#  incrleak3.0_freq0.5 ./despa_incrleak3.0_freq0.5_5.pickle
# Reading ./despa_incrleak3.0_freq0.5_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle
# #
#  incrleak3.0_freq0.1 ./despa_incrleak3.0_freq0.1_5.pickle
# Reading ./despa_incrleak3.0_freq0.1_5.pickle
# #
#  baseline_freq0.1 ./despa_baseline_freq0.1_5.pickle
# Reading ./despa_baseline_freq0.1_5.pickle
# #
#  incrleak3.0_freq1.0 ./despa_incrleak3.0_freq1.0_5.pickle
# Reading ./despa_incrleak3.0_freq1.0_5.pickle
# #
#  baseline_freq0.5 ./despa_baseline_freq0.5_5.pickle
# Reading ./despa_baseline_freq0.5_5.pickle
# #
#  incrleak3.0_freq1.5 ./despa_incrleak3.0_freq1.5_5.pickle
# Reading ./despa_incrleak3.0_freq1.5_5.pickle
# #
#  decrSERCAuptake0.5_freq0.5 ./despa_decrSERCAuptake0.5_freq0.5_5.pickle
# Reading ./despa_decrSERCAuptake0.5_freq0.5_5.pickle
# #
#  decrSERCAuptake0.5_freq1.5 ./despa_decrSERCAuptake0.5_freq1.5_5.pickle
# Reading ./despa_decrSERCAuptake0.5_freq1.5_5.pickle
# #
#  incrleak3.0_freq2.0 ./despa_incrleak3.0_freq2.0_5.pickle
# Reading ./despa_incrleak3.0_freq2.0_5.pickle
# #
#  decrSERCAuptake0.5_freq0.1 ./despa_decrSERCAuptake0.5_freq0.1_5.pickle
# Reading ./despa_decrSERCAuptake0.5_freq0.1_5.pickle
# #
#  decrSERCAuptake0.5_freq1.0 ./despa_decrSERCAuptake0.5_freq1.0_5.pickle
# Reading ./despa_decrSERCAuptake0.5_freq1.0_5.pickle
# #
#  decrSERCAuptake0.5_freq2.0 ./despa_decrSERCAuptake0.5_freq2.0_5.pickle
# Reading ./despa_decrSERCAuptake0.5_freq2.0_5.pickle
# #
#  baseline_freq2.0 ./despa_baseline_freq2.0_5.pickle
# Reading ./despa_baseline_freq2.0_5.pickle

# %%
freqi = "%3.1f"%0.1
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# +HIP (3.0x)
# Baseline (0.1 Hz)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max0_1=np.zeros(2)
min0_1=np.zeros(2)
diff0_1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)

  i=i+1

plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([290e3,292e3])

outFile="decrSERCAuptake0.5_freq0.1_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq0.1
# Baseline (0.1 Hz)
# decrSERCAuptake0.5_freq0.1
# uptake (-0.5x)
# incrleak3.0_freq0.1
# +HIP (3.0x)

# %%
freqi = "freq%3.1f"%(0.5)
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# +HIP (3.0x)
# Baseline (0.5 Hz)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)

  print max0_5, min0_5, diff0_5
  i=i+1
  print np.shape(s[:,idx])

plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([298e3,300e3])

outFile="decrSERCAuptake0.5_freq0.5_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq0.5
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)
# baseline_freq0.5
# Baseline (0.5 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)
# decrSERCAuptake0.5_freq0.5
# uptake (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)

  print max0_5, min0_5, diff0_5
  i=i+1
  print np.shape(s[:,idx])

plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)
plt.xlim([298e3,298.5e3])

outFile="decrSERCAuptake0.5_freq0.5_V.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq0.5
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)
# baseline_freq0.5
# Baseline (0.5 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)
# decrSERCAuptake0.5_freq0.5
# uptake (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)

# %%
freqi = "%3.1f"%1.0
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# Baseline (1.0 Hz)
# +HIP (3.0x)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1

plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq1.0
# +HIP (3.0x)
# baseline_freq1.0
# Baseline (1.0 Hz)
# decrSERCAuptake0.5_freq1.0
# uptake (-0.5x)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']

  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
  print np.shape(s[:,idx])

plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([298e3,298.4e3])
outFile="decrSERCAuptake0.5_freq1.0_V.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq1.0
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# baseline_freq1.0
# Baseline (1.0 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# decrSERCAuptake0.5_freq1.0
# uptake (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)

# %%
import daisychain as dc
dorun=False
if dorun:
    pickleNames = dc.daisychain(outBase = "despa_decrSERCAuptake0.5_freq1.0",dtn=60e3, iters=5)
else:
    pickleNames = dc.daisychain(outBase = "despa_decrSERCAuptake0.5_freq1.0",dtn=60e3, iters=5, namesOnly=True)

# %%
ts, allsisi, s_idx = dc.concatenateTrajs(pickleNames)
# Out:
# Reading despa_decrSERCAuptake0.5_freq1.0_1.pickle
# t
#  60000.0
# Reading despa_decrSERCAuptake0.5_freq1.0_2.pickle
# t
#  120000.0
# Reading despa_decrSERCAuptake0.5_freq1.0_3.pickle
# t
#  180000.0
# Reading despa_decrSERCAuptake0.5_freq1.0_4.pickle
# t
#  240000.0
# Reading despa_decrSERCAuptake0.5_freq1.0_5.pickle
# t
#  300000.0

# %%
label = "Cai"
plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
idx = s_idx.index(label)
plt.plot(ts,allsisi[:,idx])

outFile="decrSERCAuptake0.5_freq1.0_Cai_30s.png"

plt.legend()
plt.tight_layout()

plt.gcf().savefig(outFile)

#plt.xlim([250e3,300e3])

# %%
import daisychain as dc
dorun=False
if dorun:
    pickleNames = dc.daisychain(outBase = "despa_baseline_freq1.0",dtn=60e3, iters=5)
else:
    pickleNames = dc.daisychain(outBase = "despa_baseline_freq1.0",dtn=60e3, iters=5, namesOnly=True)

# %%
ts, allsisi, s_idx = dc.concatenateTrajs(pickleNames)
# Out:
# Reading despa_baseline_freq1.0_1.pickle
# t
#  60000.0
# Reading despa_baseline_freq1.0_2.pickle
# t
#  120000.0
# Reading despa_baseline_freq1.0_3.pickle
# t
#  180000.0
# Reading despa_baseline_freq1.0_4.pickle
# t
#  240000.0
# Reading despa_baseline_freq1.0_5.pickle
# t
#  300000.0

# %%
label = "Cai"
plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
idx = s_idx.index(label)
plt.plot(ts,allsisi[:,idx])

outFile="despa_baseline_freq1.0_Cai_30s.png"

plt.tight_layout()

plt.gcf().savefig(outFile)

# %%
freqi = "%3.1f"%1.5
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# Baseline (1.5 Hz)
# +HIP (3.0x)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max1_5=np.zeros(2)
min1_5=np.zeros(2)
diff1_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)

  i=i+1
plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([299.2e3,300e3])

outFile="decrSERCAuptake0.5_freq1.5_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq1.5
# Baseline (1.5 Hz)
# decrSERCAuptake0.5_freq1.5
# uptake (-0.5x)
# incrleak3.0_freq1.5
# +HIP (3.0x)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']

  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
  print np.shape(s[:,idx])
    
plt.xlim([298e3,298.4e3])
plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)

outFile="decrSERCAuptake0.5_freq1.5_V.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq1.5
# Baseline (1.5 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# decrSERCAuptake0.5_freq1.5
# uptake (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# incrleak3.0_freq1.5
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)

# %%
freqi = "%3.1f"%2.0
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# +HIP (3.0x)
# uptake (-0.5x)
# Baseline (2.0 Hz)

# %%
plt.figure()
i=0
max2=np.zeros(2)
min2=np.zeros(2)
diff2=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
plt.xlim([299.5e3,300e3])

outFile="decrSERCAuptake0.5_freq2.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# decrSERCAuptake0.5_freq2.0
# uptake (-0.5x)
# baseline_freq2.0
# Baseline (2.0 Hz)
# incrleak3.0_freq2.0
# +HIP (3.0x)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']

  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
  print np.shape(s[:,idx])
plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([298e3,298.4e3])

outFile="decrSERCAuptake0.5_freq2.0_V.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# decrSERCAuptake0.5_freq2.0
# uptake (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# baseline_freq2.0
# Baseline (2.0 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# incrleak3.0_freq2.0
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)

# %% [markdown]
# ## Ca_SR

# %%
freqi = "%3.1f"%0.1
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# +HIP (3.0x)
# Baseline (0.1 Hz)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max0_1=np.zeros(2)
min0_1=np.zeros(2)
diff0_1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font)    
plt.xlim([290e3,292e3])

outFile="decrSERCAuptake0.5_freq0.1_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq0.1
# Baseline (0.1 Hz)
# decrSERCAuptake0.5_freq0.1
# uptake (-0.5x)
# incrleak3.0_freq0.1
# +HIP (3.0x)

# %%
freqi = "freq%3.1f"%(0.5)
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# +HIP (3.0x)
# Baseline (0.5 Hz)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  print max0_5, min0_5, diff0_5
  i=i+1
  print np.shape(s[:,idx])
plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font) 
plt.xlim([298e3,300e3])

outFile="decrSERCAuptake0.5_freq0.5_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq0.5
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)
# baseline_freq0.5
# Baseline (0.5 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.] [ 0.  0.] [ 0.  0.]
# (600001,)
# decrSERCAuptake0.5_freq0.5
# uptake (-0.5x)
# time!
#  [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# [ 0.  0.]
#  [ 0.  0.] [ 0.  0.]
# (600001,)

# %%
freqi = "%3.1f"%1.0
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# Baseline (1.0 Hz)
# +HIP (3.0x)
# uptake (-0.5x)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font)     
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_freq1.0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq1.0
# +HIP (3.0x)
# baseline_freq1.0
# Baseline (1.0 Hz)
# decrSERCAuptake0.5_freq1.0
# uptake (-0.5x)

# %%
freqi = "%3.1f"%1.5
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font)     
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_freq1. 5_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')

# %%
freqi = "%3.1f"%2.0
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font)     
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_freq2.0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')

# %% [markdown]
# ## SL leak (decreased SERCA uptake, increased leak)

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    uptake = 0.5
    leak=3
    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_Jpump %f " % (0.0053114), # baseline
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case

    tag="decrSERCAuptake%3.1f_leak%3.1f_freq%3.1f"%(uptake,leak,freq_Hz)
    label="HIP (-SERCA uptake) (-%3.1fx)"%uptake
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_Jpump %f " % (0.0053114*uptake), # 50% of uptake 
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    
    tag="incrleak%3.1f_freq%3.1f"%(leak,freq_Hz)
    label="+HIP (%3.1fx)"%leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
#freqs = [0.1,0.5,1.0,1.5,2.0]
freqs = [1.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  decrSERCAuptake0.5_leak3.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_Jpump 0.002656  -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_decrSERCAuptake0.5_leak3.0_freq1.0.pickle  &
# #  incrleak3.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq1.0.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_Jpump 0.005311  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  decrSERCAuptake0.5_leak3.0_freq1.0 ./despa_decrSERCAuptake0.5_leak3.0_freq1.0_5.pickle
# Reading ./despa_decrSERCAuptake0.5_leak3.0_freq1.0_5.pickle
# #
#  incrleak3.0_freq1.0 ./despa_incrleak3.0_freq1.0_5.pickle
# Reading ./despa_incrleak3.0_freq1.0_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle

# %%
freqi = "%3.1f"%1.0
caseDicti = dict()
for key,case in caseDict.iteritems():
    if freqi in key:
        print case.label 
        caseDicti[case.tag]=case
# Out:
# HIP (-SERCA uptake) (-0.5x)
# +HIP (3.0x)
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1

plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_leak3.0_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# decrSERCAuptake0.5_leak3.0_freq1.0
# HIP (-SERCA uptake) (-0.5x)
# incrleak3.0_freq1.0
# +HIP (3.0x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1

plt.ylabel("Ca_SR [mM]",**font)
plt.xlabel("Time [ms]",**font)   
plt.xlim([299e3,300e3])

outFile="decrSERCAuptake0.5_leak3.0_freq1.0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# decrSERCAuptake0.5_leak3.0_freq1.0
# HIP (-SERCA uptake) (-0.5x)
# incrleak3.0_freq1.0
# +HIP (3.0x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max0_5=np.zeros(2)
min0_5=np.zeros(2)
diff0_5=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  print "time!", t
  print "TIme!", ti
  s = case.data['s']
  s_idx = case.data['s_idx']

  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
  print np.shape(s[:,idx])
    
plt.xlim([250e3,300e3])
plt.legend()
plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)

outFile="decrSERCAuptake0.5_leak3.0_freq1.0_V_1min.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# decrSERCAuptake0.5_leak3.0_freq1.0
# HIP (-SERCA uptake) (-0.5x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# incrleak3.0_freq1.0
# +HIP (3.0x)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)
# baseline_freq1.0
# Baseline (1.0 Hz)
# time! [  0.00000000e+00   1.00000000e-01   2.00000000e-01 ...,   5.99998000e+04
#    5.99999000e+04   6.00000000e+04]
# TIme! [ 240000.   240000.1  240000.2 ...,  299999.8  299999.9  300000. ]
# (600001,)

# %%
import daisychain as dc
dorun=False
if dorun:
    pickleNames = dc.daisychain(outBase = "despa_decrSERCAuptake0.5_leak3.0_freq1.0",dtn=60e3, iters=5)
else:
    pickleNames = dc.daisychain(outBase = "despa_decrSERCAuptake0.5_leak3.0_freq1.0",dtn=60e3, iters=5, namesOnly=True)

# %%
ts, allsisi, s_idx = dc.concatenateTrajs(pickleNames)
# Out:
# Reading despa_decrSERCAuptake0.5_leak3.0_freq1.0_1.pickle
# t
#  60000.0
# Reading despa_decrSERCAuptake0.5_leak3.0_freq1.0_2.pickle
# t
#  120000.0
# Reading despa_decrSERCAuptake0.5_leak3.0_freq1.0_3.pickle
# t
#  180000.0
# Reading despa_decrSERCAuptake0.5_leak3.0_freq1.0_4.pickle
# t
#  240000.0
# Reading despa_decrSERCAuptake0.5_leak3.0_freq1.0_5.pickle
# t
#  300000.0

# %%
label = "Cai"
idx = s_idx.index(label)
plt.plot(ts,allsisi[:,idx])
plt.ylabel("Cai [mM]",**font)
plt.xlabel("Time [ms]",**font)
outFile="decrSERCAuptake0.5_leak3.0_freq1.0_5min.png"
plt.gcf().savefig(outFile, dpi=300)

# %%
label = "V"
idx = s_idx.index(label)
plt.plot(ts,allsisi[:,idx])
plt.ylabel("V [V]",**font)
plt.xlabel("Time [ms]",**font)
outFile="decrSERCAuptake0.5_leak3.0_freq1.0_V_5min.png"
plt.gcf().savefig(outFile, dpi=300)

# %% [markdown]
# ## Increased LCC current, Up-regulated SL current

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    lcc_leak = 1.4

    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var PCa %f " % (0.00054), # baseline leak
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case

    tag="incrLCCleak%3.1f_freq%3.1f"%(lcc_leak,freq_Hz)
    label="+LCC current (%3.1fx)"%lcc_leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var PCa %f " % (0.00054*lcc_leak), # baseline times 1.5
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [1.0,]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  incrLCCleak1.4_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var PCa 0.000756  -iters 5 -T 60000.000000 -name ./despa_incrLCCleak1.4_freq1.0.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var PCa 0.000540  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  incrLCCleak1.4_freq1.0 ./despa_incrLCCleak1.4_freq1.0_5.pickle
# Reading ./despa_incrLCCleak1.4_freq1.0_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrLCCleak1.4_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrLCCleak1.4_freq1.0
# +LCC current (1.4x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Ca_SR [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrLCCleak1.4_freq1.0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrLCCleak1.4_freq1.0
# +LCC current (1.4x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("V")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("V [V]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrLCCleak1.4_freq1.0_V.png"
plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrLCCleak1.4_freq1.0
# +LCC current (1.4x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %% [markdown]
# ## Increased NCX Vmax, Up-regulated SL current

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    ncx_leak = 1.5

    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1

    tag="incrNCXleak%3.1f_freq%3.1f"%(ncx_leak,freq_Hz)
    label="+NCX leak (%3.1fx)"%ncx_leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_INaCa %f " % (9*ncx_leak), # baseline times 1.5
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var V_max_INaCa %f " % (9), # baseline leak
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    return caseDict

# %%
freqs = [1.0,]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  incrNCXleak1.5_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_INaCa 13.500000  -iters 5 -T 60000.000000 -name ./despa_incrNCXleak1.5_freq1.0.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var V_max_INaCa 9.000000  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  incrNCXleak1.5_freq1.0 ./despa_incrNCXleak1.5_freq1.0_5.pickle
# Reading ./despa_incrNCXleak1.5_freq1.0_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrNCXleak1.5_freq1.0
# +NCX leak (1.5x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Ca_SR [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrNCXleak1.5_freq1.0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrNCXleak1.5_freq1.0
# +NCX leak (1.5x)
# baseline_freq1.0
# Baseline (1.0 Hz)

# %% [markdown]
# ## Increased Na conductance

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    na_leak = 2.0

    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1

    tag="incrNaiLeak%3.1f_freq%3.1f"%(na_leak,freq_Hz)
    label="+G_NaBk (%3.1fx)"%na_leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297*na_leak), # baseline times 1.5
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297), # baseline leak
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    return caseDict

# %%
freqs = [0.1,0.5,1.0,1.5,2.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  baseline_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.5.pickle  &
# #  incrNaiLeak2.0_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak2.0_freq2.0.pickle  &
# #  incrNaiLeak2.0_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak2.0_freq1.5.pickle  &
# #  incrNaiLeak2.0_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak2.0_freq0.1.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &
# #  incrNaiLeak2.0_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak2.0_freq0.5.pickle  &
# #  baseline_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.1.pickle  &
# #  baseline_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq2.0.pickle  &
# #  incrNaiLeak2.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak2.0_freq1.0.pickle  &
# #  baseline_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.5.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  baseline_freq1.5 ./despa_baseline_freq1.5_5.pickle
# Reading ./despa_baseline_freq1.5_5.pickle
# #
#  incrNaiLeak2.0_freq2.0 ./despa_incrNaiLeak2.0_freq2.0_5.pickle
# Reading ./despa_incrNaiLeak2.0_freq2.0_5.pickle
# #
#  incrNaiLeak2.0_freq1.5 ./despa_incrNaiLeak2.0_freq1.5_5.pickle
# Reading ./despa_incrNaiLeak2.0_freq1.5_5.pickle
# #
#  incrNaiLeak2.0_freq0.1 ./despa_incrNaiLeak2.0_freq0.1_5.pickle
# Reading ./despa_incrNaiLeak2.0_freq0.1_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle
# #
#  incrNaiLeak2.0_freq0.5 ./despa_incrNaiLeak2.0_freq0.5_5.pickle
# Reading ./despa_incrNaiLeak2.0_freq0.5_5.pickle
# #
#  baseline_freq0.1 ./despa_baseline_freq0.1_5.pickle
# Reading ./despa_baseline_freq0.1_5.pickle
# #
#  baseline_freq2.0 ./despa_baseline_freq2.0_5.pickle
# Reading ./despa_baseline_freq2.0_5.pickle
# #
#  incrNaiLeak2.0_freq1.0 ./despa_incrNaiLeak2.0_freq1.0_5.pickle
# Reading ./despa_incrNaiLeak2.0_freq1.0_5.pickle
# #
#  baseline_freq0.5 ./despa_baseline_freq0.5_5.pickle
# Reading ./despa_baseline_freq0.5_5.pickle

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrNaiLeak2.0_freq2.0
# +G_NaBk (2.0x)
# baseline_freq2.0
# Baseline (2.0 Hz)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Nai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Nai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrNaiLeak2.0_freq2.0
# +G_NaBk (2.0x)
# baseline_freq2.0
# Baseline (2.0 Hz)

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    na_leak = 4.0

    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1

    tag="incrNaiLeak%3.1f_freq%3.1f"%(na_leak,freq_Hz)
    label="+G_NaBk (%3.1fx)"%na_leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297*na_leak), # baseline times 1.5
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297), # baseline leak
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    return caseDict

# %%
freqs = [0.1,0.5,1.0,1.5,2.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  baseline_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.5.pickle  &
# #  incrNaiLeak4.0_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak4.0_freq0.5.pickle  &
# #  incrNaiLeak4.0_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak4.0_freq0.1.pickle  &
# #  incrNaiLeak4.0_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak4.0_freq2.0.pickle  &
# #  incrNaiLeak4.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak4.0_freq1.0.pickle  &
# #  baseline_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.1.pickle  &
# #  baseline_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq2.0.pickle  &
# #  incrNaiLeak4.0_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak4.0_freq1.5.pickle  &
# #  baseline_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.5.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  baseline_freq1.5 ./despa_baseline_freq1.5_5.pickle
# Reading ./despa_baseline_freq1.5_5.pickle
# #
#  incrNaiLeak4.0_freq0.5 ./despa_incrNaiLeak4.0_freq0.5_5.pickle
# Reading ./despa_incrNaiLeak4.0_freq0.5_5.pickle
# #
#  incrNaiLeak4.0_freq0.1 ./despa_incrNaiLeak4.0_freq0.1_5.pickle
# Reading ./despa_incrNaiLeak4.0_freq0.1_5.pickle
# #
#  incrNaiLeak4.0_freq2.0 ./despa_incrNaiLeak4.0_freq2.0_5.pickle
# Reading ./despa_incrNaiLeak4.0_freq2.0_5.pickle
# #
#  incrNaiLeak4.0_freq1.0 ./despa_incrNaiLeak4.0_freq1.0_5.pickle
# Reading ./despa_incrNaiLeak4.0_freq1.0_5.pickle
# #
#  baseline_freq0.1 ./despa_baseline_freq0.1_5.pickle
# Reading ./despa_baseline_freq0.1_5.pickle
# #
#  baseline_freq2.0 ./despa_baseline_freq2.0_5.pickle
# Reading ./despa_baseline_freq2.0_5.pickle
# #
#  incrNaiLeak4.0_freq1.5 ./despa_incrNaiLeak4.0_freq1.5_5.pickle
# Reading ./despa_incrNaiLeak4.0_freq1.5_5.pickle
# #
#  baseline_freq0.5 ./despa_baseline_freq0.5_5.pickle
# Reading ./despa_baseline_freq0.5_5.pickle
# #
#  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq2.0
# Baseline (2.0 Hz)
# incrNaiLeak4.0_freq2.0
# +G_NaBk (4.0x)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Nai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Nai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq2.0
# Baseline (2.0 Hz)
# incrNaiLeak4.0_freq2.0
# +G_NaBk (4.0x)

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    na_leak = 6.0

    # for storing data 
    caseDict = dict()

    #### Define cases 
    # case 1

    tag="incrNaiLeak%3.1f_freq%3.1f"%(na_leak,freq_Hz)
    label="+G_NaBk (%3.1fx)"%na_leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297*na_leak), # baseline times 1.5
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_NaBk %f " % (0.000297), # baseline leak
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
    return caseDict

# %%
freqs = [0.1,0.5,1.0,1.5,2.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  baseline_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.5.pickle  &
# #  incrNaiLeak6.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.001782  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak6.0_freq1.0.pickle  &
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &
# #  incrNaiLeak6.0_freq1.5
# python daisychain.py  -var stim_period 666.666667 -var G_NaBk 0.001782  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak6.0_freq1.5.pickle  &
# #  baseline_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.1.pickle  &
# #  baseline_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq2.0.pickle  &
# #  incrNaiLeak6.0_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.001782  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak6.0_freq0.5.pickle  &
# #  incrNaiLeak6.0_freq2.0
# python daisychain.py  -var stim_period 500.000000 -var G_NaBk 0.001782  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak6.0_freq2.0.pickle  &
# #  baseline_freq0.5
# python daisychain.py  -var stim_period 2000.000000 -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq0.5.pickle  &
# #  incrNaiLeak6.0_freq0.1
# python daisychain.py  -var stim_period 10000.000000 -var G_NaBk 0.001782  -iters 5 -T 60000.000000 -name ./despa_incrNaiLeak6.0_freq0.1.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  baseline_freq1.5 ./despa_baseline_freq1.5_5.pickle
# Reading ./despa_baseline_freq1.5_5.pickle
# #
#  incrNaiLeak6.0_freq1.0 ./despa_incrNaiLeak6.0_freq1.0_5.pickle
# Reading ./despa_incrNaiLeak6.0_freq1.0_5.pickle
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-264-9e1853ec7322> in <module>()
#       3 for key,case in caseDict.iteritems():
#       4       print "# ", key, case.name
# ----> 5       case.data = ao.readPickle(case.name)
#
# /home/AD/cesc235/wholecell_new3/asdf/wholecell/analyzeODE.pyc in readPickle(name)
#      19 def readPickle(name = "PCa0.75kss0.25.pickle"):
#      20   print "Reading " + name
# ---> 21   pkl_file = open(name, 'rb')
#      22   data1 = pickle.load(pkl_file)
#      23   pkl_file.close()
#
# IOError: [Errno 2] No such file or directory: './despa_incrNaiLeak6.0_freq1.0_5.pickle'

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Cai")
  plt.plot(ti,s[:,idx],label=case.label)

  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq2.0
# Baseline (2.0 Hz)
# incrNaiLeak6.0_freq2.0
# +G_NaBk (6.0x)

# %%
plt.figure()
i=0
max1=np.zeros(2)
min1=np.zeros(2)
diff1=np.zeros(2)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']


  idx = s_idx.index("Nai")
  plt.plot(ti,s[:,idx],label=case.label)
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Nai [mM]", **font)
plt.xlabel("Time [ms]",**font)

#outFile="incrNCXleak1.5_freq1.0_Cai.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

#plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq2.0
# Baseline (2.0 Hz)
# incrNaiLeak6.0_freq2.0
# +G_NaBk (6.0x)

# %% [markdown]
# ## Different leaks

# %% [markdown]
# ### leaks = 1.0, 2.0, 3.0, 4.0

# %% [markdown]
# ###### leak = 1.0

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    leak=1.0
    # for storing data 
    caseDict = dict()

    # case 1
    tag="baseline_freq%3.1f"%freq_Hz
    label="Baseline (%3.1f Hz)"%freq_Hz
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513), # baseline
      "-var G_NaBk %f " % (0.000297) # baseline
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [1.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  baseline_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.000251  -var G_NaBk 0.000297  -iters 5 -T 60000.000000 -name ./despa_baseline_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  baseline_freq1.0 ./despa_baseline_freq1.0_5.pickle
# Reading ./despa_baseline_freq1.0_5.pickle

# %%
plt.figure()
i=0
max1=np.zeros(1)
min1=np.zeros(1)
diff1=np.zeros(1)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']
  print np.shape(s_idx)

  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  max1[i] = np.amax(s[590e3:,idx])
  min1[i] = np.amin(s[590e3:,idx])
  diff1[i] = max1[i] - min1[i]
  print max1, min1, diff1
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrleak1p0_freq1p0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# baseline_freq1.0
# Baseline (1.0 Hz)
# (39,)
# [ 0.54890524]
#  [ 0.32214501] [ 0.22676023]

# %% [markdown]
# ###### leak = 2.0

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    leak=2.0
    # for storing data 
    caseDict = dict()
    
    tag="incrleak%3.1f_freq%3.1f"%(leak,freq_Hz)
    label="+HIP (%3.1fx)"%leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [1.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  incrleak2.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.000503  -var G_NaBk 0.000594  -iters 5 -T 60000.000000 -name ./despa_incrleak2.0_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  incrleak2.0_freq1.0 ./despa_incrleak2.0_freq1.0_5.pickle
# Reading ./despa_incrleak2.0_freq1.0_5.pickle

# %%
plt.figure()
i=0
max2=np.zeros(1)
min2=np.zeros(1)
diff2=np.zeros(1)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']
  print np.shape(s_idx)

  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  max2[i] = np.amax(s[590e3:,idx])
  min2[i] = np.amin(s[590e3:,idx])
  diff2[i] = max2[i] - min2[i]
  print max1, min1, diff1
  print max2, min2, diff2
  i=i+1
    
#plt.figure()
#idx = s_idx.index("Nai")
#plt.plot(t,s[:,idx],label=case.label)
plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrleak2p0_freq1p0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak2.0_freq1.0
# +HIP (2.0x)
# (39,)
# [ 0.54890524]
#  [ 0.32214501] [ 0.22676023]
# [ 0.56135101] [ 0.312304] [ 0.24904702]

# %% [markdown]
# ###### leak = 3.0

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    leak=3.0
    # for storing data 
    caseDict = dict()

    #### Define cases 

    tag="incrleak%3.1f_freq%3.1f"%(leak,freq_Hz)
    label="+HIP (%3.1fx)"%leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [1.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  incrleak3.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.000754  -var G_NaBk 0.000891  -iters 5 -T 60000.000000 -name ./despa_incrleak3.0_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  incrleak3.0_freq1.0 ./despa_incrleak3.0_freq1.0_5.pickle
# Reading ./despa_incrleak3.0_freq1.0_5.pickle

# %%
plt.figure()
i=0
max3=np.zeros(1)
min3=np.zeros(1)
diff3=np.zeros(1)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']
  print np.shape(s)

  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  max3[i] = np.amax(s[590e3:,idx])
  min3[i] = np.amin(s[590e3:,idx])
  diff3[i] = max3[i] - min3[i]
  print max3, min3, diff3
  print max2, min2, diff2
  print max1, min1, diff1
  
  i=i+1
    

plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrleak3p0_freq1p0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak3.0_freq1.0
# +HIP (3.0x)
# (600001, 39)
# [ 0.57379485]
#  [ 0.30216401] [ 0.27163085]
# [ 0.56135101] [ 0.312304] [ 0.24904702]
# [ 0.54890524] [ 0.32214501] [ 0.22676023]

# %% [markdown]
# ##### leak = 4.0

# %%
import Case
T = 300e3             # total simulation time [ms]
nIntervals = 5       # number of intervals (s.t. each pickle contains T/nInterval of data )

def init(freq_Hz=1.,
         T=300e3, # total simulation time [ms]
         nIntervals=6 # number of intervals (s.t. each pickle contains T/nInterval of data )

         ):
    #### Define common parameters    
    root = "./"
    stim_period = 1000./freq_Hz  # ms
    leak=4.0
    # for storing data 
    caseDict = dict()
    
    tag="incrleak%3.1f_freq%3.1f"%(leak,freq_Hz)
    label="+HIP (%3.1fx)"%leak
    name = root+"despa_%s.pickle"%(tag) # filename 
    args = [ # pass in cellml/gotran arguments (eg. in shannon_2004.ode)
      "-var stim_period %f" % stim_period,
      "-var G_CaBk %f " % (0.0002513*leak), # baseline times 3.0
      "-var G_NaBk %f " % (0.000297*leak) # baseline times 3.0 
      ]
    case = Case.Case(tag=tag,label=label,args=args,nIntervals=nIntervals,T=T, name = name)
    caseDict[tag] = case
  
    return caseDict

# %%
freqs = [1.0]

caseDict = dict()
for i,freq in enumerate(freqs):
  caseDicti = init(freq_Hz=freq, T=T,nIntervals=nIntervals)   
  caseDict.update(caseDicti)

# %%
for key,case in caseDict.iteritems():
      print "# ", key
      print case.cmdLine
  #print "python runShannonTest.py "+" ".join(healthyArgs)+" -name "+healthyName+" &"
# Out:
# #  incrleak4.0_freq1.0
# python daisychain.py  -var stim_period 1000.000000 -var G_CaBk 0.001005  -var G_NaBk 0.001188  -iters 5 -T 60000.000000 -name ./despa_incrleak4.0_freq1.0.pickle  &

# %%
import analyzeODE as ao

for key,case in caseDict.iteritems():
      print "# ", key, case.name
      case.data = ao.readPickle(case.name)
# Out:
# #  incrleak4.0_freq1.0 ./despa_incrleak4.0_freq1.0_5.pickle
# Reading ./despa_incrleak4.0_freq1.0_5.pickle

# %%
plt.figure()
i=0
max4=np.zeros(1)
min4=np.zeros(1)
diff4=np.zeros(1)
for key, case in caseDicti.iteritems():
  print case.tag
  print case.label
  t = case.data['t'] 
  #t-= np.min(t)  
  ti= t + T*(1-1/np.float(nIntervals)) # should define this elsewhere (dbl check) 
  s = case.data['s']
  s_idx = case.data['s_idx']
  print np.shape(s)

  idx = s_idx.index("Ca_SR")
  plt.plot(ti,s[:,idx],label=case.label)
  max4[i] = np.amax(s[590e3:,idx])
  min4[i] = np.amin(s[590e3:,idx])
  diff4[i] = max4[i] - min4[i]
  print max4, min4, diff4
  print max3, min3, diff3
  print max2, min2, diff2
  print max1, min1, diff1
  
  i=i+1
    

plt.xlim([299e3,300e3])
plt.ylabel("Cai [mM]", **font)
plt.xlabel("Time [ms]",**font)

outFile="incrleak4p0_freq1p0_CaSR.png"

plt.legend(bbox_to_anchor=(1.75,1.0),fancybox=True, shadow=True)
plt.tight_layout()

plt.gcf().savefig(outFile,bbox_extra_Artists=(),bbox_inches='tight')
# Out:
# incrleak4.0_freq1.0
# +HIP (4.0x)
# (600001, 39)
# [ 0.58641075]
#  [ 0.29185657] [ 0.29455418]
# [ 0.57379485] [ 0.30216401] [ 0.27163085]
# [ 0.56135101] [ 0.312304] [ 0.24904702]
# [ 0.54890524] [ 0.32214501] [ 0.22676023]

# %% [markdown]
# #### Compare all data across different leaks

# %%
max_y=np.array([max1, max2, max3, max4])
min_y=np.array([min1, min2, min3, min4])
leak=np.linspace(1.0, 4.0, 4.0)
print leak
# Out:
# [ 1.  2.  3.  4.]

# %%
ax1 = plt.subplot(1,1,1)

#############

ax1.plot(leak,min_y,label="Minimum")

ax1.plot(leak,max_y,label="Maximum")

ax1.set_xlim([0,5.0])
ax1.set_ylim([0,0.75])
ax1.set_ylabel("Ca_SR [mM]",**font)
ax1.set_xlabel("Leak Rate",**font)
ax1.set_title("Ca_SR")

plt.legend(loc=0, ncol=2)
plt.tight_layout()
plt.gcf().savefig('/net/share/cesc235/pkh-lab-papers/150817_despa/figs/diff_CaSRConc.png',dpi=300)
