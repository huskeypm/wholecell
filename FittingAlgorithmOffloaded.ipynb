# %% [markdown]
# ## Offloaded

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.append("./fitting_sensitivity")

# %%
import fittingAlgorithm as fitA
# Out:
# WARNING: ode idx is hardcoded

# %%
fitA.validation(numIters = 2)
# Out:
# parmDict:  {'Bmax_SL': [10.0, 1.0]}
# Inputs:  Bmax_SL 10.0
# Using 2 cores for 2 jobs
# Bmax_SL  random draws:
# sigma:  1.0
# rescaledSigma:  1.0
# [  9.619879    10.07833255]
# Multi-threading
# myDataFrame:
#         Bmax_SL        Nai   jobID
# 0_9739  9.61988  0.0110717  0_9739
# 1_9740  10.0783   0.011065  1_9740
# jobFitnesses:  [  8.61704328e-07   8.74190566e-07]
# jobIndex:  0
# bestVarDict:  {'Bmax_SL': 9.6198789950942167}
# iters:  1
#
# ######
#
# parmDict:  {'Bmax_SL': [9.6198789950942167, 1.0]}
# Inputs:  Bmax_SL 9.61987899509
# Using 2 cores for 2 jobs
# Bmax_SL  random draws:
# sigma:  1.0
# rescaledSigma:  0.5
# [ 9.6660594   9.73237329]
# Multi-threading
# Worker bee 9739, Job 0
# Worker bee 9740, Job 1
# Loaded ODE model 'shannon_2004_mouse' with:
# Loaded ODE model 'shannon_2004_mouse' with:
#      Num full states: 43
#      Num full states: 43
#       Num parameters: 133
#       Num parameters: 133
# ...

# %%
numRandomDraws = 10
numCores = numRandomDraws
numIters = 10

fitA.validation(numRandomDraws=numRandomDraws,numCores=numCores, numIters=numIters)
# Out:
# parmDict:  {'Bmax_SL': [10.0, 1.0]}
# Inputs:  Bmax_SL 10.0
# Using 10 cores for 10 jobs
# Bmax_SL  random draws:
# [ 11.19403582   9.06580207   8.85455169   8.31519517   9.36745445
#    7.03785556  10.12771211   8.65055705   9.79659675   9.11173817]
# Multi-threading
# myDataFrame:
#         Bmax_SL        Nai   jobID
# 0_9835   11.194  0.0110487  0_9835
# 1_9836   9.0658  0.0110798  1_9836
# 2_9837  8.85455  0.0110829  2_9837
# 3_9838   8.3152  0.0110908  3_9838
# 4_9839  9.36745  0.0110754  4_9839
# 5_9840  7.03786  0.0111095  5_9840
# 6_9841  10.1277  0.0110643  6_9841
# 7_9842  8.65056  0.0110859  7_9842
# 8_9843   9.7966  0.0110691  8_9843
# 9_9844  9.11174  0.0110792  9_9844
# jobFitnesses:  [  9.04923453e-07   8.46724593e-07   8.41045336e-07   8.26625532e-07
#    8.54864850e-07   7.92936864e-07   8.75540395e-07   8.35577929e-07
#    8.66507506e-07   8.47961879e-07]
# jobIndex:  5
# bestVarDict:  {'Bmax_SL': 7.0378555613385583}
# iters:  1
#
# ######
#
# ...
