# %% [markdown]
# python runShannonTest.py -stim 1000 -jit -T 30000 -var PCa 0.001080 -var lccCaInact 5.950000 -name test_incrLCC_1000.pickle &

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import analyzeODE as ao
import numpy as np
#data = ao.readPickle("test_incrLCC_1000.pickle")
# Out:
# WARNING: ode idx is hardcoded

# %%
from runShannonTest import *

# %%
si = data0['s']
s_idx = data0['s_idx']
t = data0['t']

label = "Cai"
idx = s_idx.index(label)
plt.plot(t,si[:,idx])
print idx
#plt.xlim([250e3,300e3])
# Out:
# 37

# %% [markdown]
# #### Time=100 s; stim_period=0.5 s; frequency = 2 Hz

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 1: 
  data0 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim500.pickle")
  data1 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim500.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim500.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim500.pickle

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data0
s0 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s0[:,idx],label="Baseline")
max2b = np.amax(s0[50000:100000,idx])
min2b = np.amin(s0[50000:100000,idx])
print max2b, min2b

data = data1
s1 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s1[:,idx],label="3x")
max2x = np.amax(s1[50000:100000,idx])
min2x = np.amin(s1[50000:100000,idx])
print max2x, min2x

ax1.set_xlim([99500,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

#plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000493787195482 0.000113866102854
# 0.000551235737964 0.000117801095917

# %% [markdown]
# #### Time=100 s; stim_period=0.667 s; frequency = 1.5 Hz

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 1: 
  data2 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim667.pickle")
  data3 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim667.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim667.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim667.pickle

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data2
s2 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s2[:,idx],label="Baseline")
max1_5b = np.amax(s2[50000:100000,idx])
min1_5b = np.amin(s2[50000:100000,idx])
print max1_5b, min1_5b

data = data3
s3 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s3[:,idx],label="3x")
max1_5x = np.amax(s3[50000:100000,idx])
min1_5x = np.amin(s3[50000:100000,idx])
print max1_5x, min1_5x

ax1.set_xlim([99300,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

#plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000437119613829 9.70987688321e-05
# 0.000499404526227 0.000100900691315

# %% [markdown]
# #### Time=100 s; stim_period=1.0 s; frequency = 1 Hz

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 1: 
  data4 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle")
  data5 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim1000.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim1000.pickle

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data4
s4 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s4[:,idx],label="Baseline")
max1b = np.amax(s4[50000:100000,idx])
min1b = np.amin(s4[50000:100000,idx])
print max1b, min1b

data = data5
s5 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s5[:,idx],label="3x")
max1x = np.amax(s5[50000:100000,idx])
min1x = np.amin(s5[50000:100000,idx])
print max1x, min1x

ax1.set_xlim([99000,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

#plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000379380654027 8.66308829395e-05
# 0.000454322636966 9.11752682765e-05

# %% [markdown]
# #### Time=100 s; stim_period=2 s; frequency = 0.5 Hz

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 1: 
  data6 = ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle")
  data7 = ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim2000.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim2000.pickle

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data6
s6 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s6[:,idx],label="Baseline")
max0_5b = np.amax(s6[50000:100000,idx])
min0_5b = np.amin(s6[50000:100000,idx])
print max0_5b, min0_5b

data = data7
s7 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s7[:,idx],label="3x")
max0_5x = np.amax(s7[50000:100000,idx])
min0_5x = np.amin(s7[50000:100000,idx])
print max0_5x, min0_5x

ax1.set_xlim([98000,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

#plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000313760959478 8.05268699744e-05
# 0.000420952866183 8.66123974625e-05

# %% [markdown]
# #### Time=100 s; stim_period=10 s; frequency = 0.1 Hz

# %%
root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 1: 
  data8= ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim10000.pickle")
  data9= ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim10000.pickle")
# Out:
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk1.00_G_NaBk1.00_stim10000.pickle
# Reading /home/AD/cesc235/wholecell_new3/wholecell/run_G_CaBk3.00_G_NaBk3.00_stim10000.pickle

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data8
s8 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s8[:,idx],label="Baseline")
max0_1b = np.amax(s8[50000:100000,idx])
min0_1b = np.amin(s8[50000:100000,idx])
print max0_1b, min0_1b

data = data9
s9 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s9[:,idx],label="3x")
max0_1x = np.amax(s9[50000:100000,idx])
min0_1x = np.amin(s9[50000:100000,idx])
print max0_1x, min0_1x

ax1.set_xlim([90000,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

#plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000265699869111 7.5054391005e-05
# 0.000564126029035 8.42046507959e-05

# %%
import analyzeODE as ao


root = "/home/AD/cesc235/wholecell_new3/wholecell/"
versionPrefix = "150721_"

if 0: 
  data8= ao.readPickle(root+"run_G_CaBk1.00_G_NaBk1.00_stim10000.pickle")
  data9= ao.readPickle(root+"run_G_CaBk3.00_G_NaBk3.00_stim10000.pickle")

data = data8
s8 = data['s']
t = data['t']
label = "Cai"
idx = s_idx.index(label)
plot(t,s8[:,idx],label="Baseline")


data = data9
s9 = data['s']
t = data['t']
s_idx = data['s_idx'] 
idx = s_idx.index(label)
plot(t,s9[:,idx],label="3x")

# %% [markdown]
# # FIGURES

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data6
s6 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s6[:,idx],label="Baseline")
max0_5b = np.amax(s6[50000:100000,idx])
min0_5b = np.amin(s6[50000:100000,idx])
print max0_5b, min0_5b

data = data7
s7 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s7[:,idx],label="3x")
max0_5x = np.amax(s7[50000:100000,idx])
min0_5x = np.amin(s7[50000:100000,idx])
print max0_5x, min0_5x

ax1.set_xlim([98000,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5A.png',dpi=300)
# Out:
# 0.000313760959478 8.05268699744e-05
# 0.000420952866183 8.66123974625e-05

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

data = data0
s0 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s0[:,idx],label="Baseline")

data = data1
s1 = data['s']
t = data['t']
s_idx = data['s_idx'] 
ax1.plot(t,s1[:,idx],label="3x")

ax1.set_xlim([99500,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5B.png',dpi=300)

# %%
ax1 = plt.subplot(1,1,1)

#############
idxCai = runner.model.state_indices("Cai")

minb = np.amin(s6[98000:100000,idx])
s6_shift = s6[98000:100000,idx]-minb
maxb = np.amax(s6_shift)
s6_shift/=maxb

minx = np.amin(s7[98000:100000,idx])
s7_shift = s7[98000:100000,idx]-minx
maxx = np.amax(s7_shift)
s7_shift/=maxx

ax1.plot(t[98000:100000],s6_shift,label="Baseline, 0.5 Hz")
ax1.plot(t[98000:100000],s7_shift,label="3x Leak, 0.5 Hz")

ax1.set_xlim([98000,100000])
ax1.set_ylabel("Cai [mM]")
ax1.set_xlabel("t [ms]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=3)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5C.png',dpi=300)

# %%
diff0_1b = max0_1b-min0_1b
diff0_1x = max0_1x-min0_1x
diff0_5b = max0_5b-min0_5b
diff0_5x = max0_5x-min0_5x
diff1b = max1b-min1b
diff1x = max1x-min1x
diff1_5b = max1_5b-min1_5b
diff1_5x = max1_5x-min1_5x
diff2b = max2b-min2b
diff2x = max2x-min2x

ctl_y=np.array([diff0_1b, diff0_5b, diff1b, diff1_5b, diff2b])
pd_y=np.array([diff0_1x, diff0_5x, diff1x, diff1_5x, diff2x])
freq=np.arange(0.5,2.5,0.5)
freq0=0.1
freq_x=np.insert(freq,0,freq0)
print freq_x

ax1 = plt.subplot(1,2,1)

#############

ax1.plot(freq_x,ctl_y,label="Baseline")

ax1.plot(freq_x,pd_y,label="3x Leak")

ax1.set_xlim([0,2.5])
ax1.set_ylabel("Difference in Cai [mM]")
ax1.set_xlabel("Frequency [Hz]")
ax1.set_title("Cai")

plt.legend(loc=0, ncol=2)
plt.tight_layout()

plt.gcf().savefig(root+versionPrefix+'figure5D.png',dpi=300)
# Out:
# [ 0.1  0.5  1.   1.5  2. ]
